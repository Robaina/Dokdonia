# %%
import pandas as pd
import numpy as np
import os
import json
import copy
from matplotlib import pyplot as plt
from matplotlib_venn import venn2
import Dokdonia_code as Dc
# plt.style.use('plt_styles.mplstyle')
# %matplotlib inline
# Out:
#     <script>
#       if(typeof mergeNodes !== "Undefined") {{
#          let mergeNodes;
#       }}
#       mergeNodes = function(a, b) {{
#         return [].slice.call(a).concat([].slice.call(b));
#       }}; // http://stackoverflow.com/questions/914783/javascript-nodelist/17262552#17262552
#
#       function interactUpdate(elem){{
#          let div = elem.parentNode;
#
#          if(elem.type === "range") {{
#             let label = document.getElementById(elem.id + "_label");
#             label.innerHTML = elem.value; // update label with input value
#          }}
#
#          let outputs = div.getElementsByTagName("div");
#          //let controls = div.getElementsByTagName("input");
#          let controls = mergeNodes(div.getElementsByTagName("input"), div.getElementsByTagName("select"));
#          function nameCompare(a,b) {{
#             return a.getAttribute("name").localeCompare(b.getAttribute("name"));
#          }}
#          controls.sort(nameCompare);
#
#          let value = "";
#          for(i=0; i<controls.length; i++){{
#            if((controls[i].type == "range") || controls[i].checked){{
#              value = value + controls[i].getAttribute("name") + controls[i].value;
#            }}
#            if(controls[i].type == "select-one"){{
#              value = value + controls[i].getAttribute("name") + controls[i][controls[i].selectedIndex].value;
#            }}
#          }}
#          value = value.replace(/\s/g,"");
#          for(i=0; i<outputs.length; i++){{
#            let name = outputs[i].getAttribute("name");
#            if(name == value){{
#               outputs[i].style.display = 'block';
#            }} else if(name != "controls"){{
#               outputs[i].style.display = 'none';
#            }}
#          }}
#       }}
#     </script>

# %% [markdown]
# # Analysis of differential expression

# %%
# Loading counts and removing genes with low read counts across samples
min_count = 10

counts = pd.read_csv('Data/DokdoniaCounts.csv', index_col=0)
counts = counts[counts.filter(regex='^[^T]+$').columns]
conditions = [name.split('.sam')[0] for name in counts.columns]
counts.columns = conditions
counts = counts[(counts > min_count).all(1)]
counts.reset_index(level=0, inplace=True)
counts.head()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#           index  D_10_R1  D_10_R2  D_10_R3  D_18_R1  D_18_R2  D_18_R3  \
# 0  MED134_07389    12973    11426    13251    30624    30618    41014
# 1  MED134_07384     1557     1555     1552     4160     4385     5588
# 2  MED134_07379     3400     3319     3273     7218     7903     9539
# 3  MED134_07374     1987     2124     1404     3509     3772     4337
# 4  MED134_07369     2087     2010     2111     3774     3809     4486
#
#    D_18_R4  D_25_R1  D_25_R2  ...  L_18_R2  L_18_R3  L_18_R4  L_25_R1  \
# 0    22449    53840    32369  ...    16255    23945    20102    39444
# 1     2940     7550     4509  ...     2564     3003     2894     5419
# 2     5040    13268     7572  ...     4575     5361     4923     9089
# 3     2602     4607     3316  ...     1798     2558     2637     3586
# 4     2901     4668     3456  ...     2545     3456     3008     3705
#
#    L_25_R2  L_25_R3  L_34_R1  L_34_R2  L_34_R3  L_34_R4
# 0    41721    37020    39662    30983    27280    57834
# 1     5536     5318     5396     4751     4285     7818
# 2     9016     8529    10179     7617     7207    13827
# 3     3594     3488     4158     3096     2623     5323
# 4     4158     3760     5518     3563     2713     5150
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Light vs dark conditions

# %% [markdown]
# ## Across temperatures

# %%
DE_results = Dc.readFromPickleFile('Results/DE_result.pkl')
len(DE_results['all'])
# Out:
# 1930

# %%
# Prepara plot data
p_Data_paths, cluster_data, clusters = {}, {}, {}
data_types = ['TC', 'TPM']
res_ids = ['CLUSTER_ALL_GENES_TRANSCRIPT_CELL', 'CLUSTER_ALL_GENES_TPM']

for data_type, res_id in zip(data_types, res_ids):
    
    p_KEGG_paths = Dc.readFromPickleFile(
        path_to_file=f'Results/Permutation_analysis/p_KEGG_paths_500000_{res_id}.pkl')
    p_PATRIC_paths = Dc.readFromPickleFile(
        path_to_file=f'Results/Permutation_analysis/p_PATRIC_paths_500000_{res_id}.pkl')
    c_data = pd.read_csv(os.path.join(
        os.getcwd(),f'Results/{res_id}/Processed_Data/clust_input.tsv_processed.tsv'),
                        sep='\t', index_col='Genes')
    # Add fake column to separate datasets
    c_data.insert(4, '', [np.nan for n in range(c_data.shape[0])])

    clusts = Dc.readFromPickleFile(path_to_file=f'Results/Clusters_{res_id}.pkl')
    clusts = {k: v for k,v in clusts.items() if k != 'No_cluster_assigned'}
    
    p_Data_paths[data_type] = {'KEGG': p_KEGG_paths, 'PATRIC': p_PATRIC_paths}
    cluster_data[data_type] = c_data
    clusters[data_type] = clusts

# %% [markdown]
# ## Using the silhouette to rank genes within cluster
#
# We can calculate the silhouette of each gene in a cluster to rank them based on how well they fit in the cluster. We can also use the silhouette to assess how good the clusters are.
#
# From Wikipedia:
#
# "The silhouette value is a measure of how similar an object is to its own cluster (cohesion) compared to other clusters (separation). The silhouette ranges from −1 to +1, where a high value indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters."
#
# The silhouette compares the mean within-cluster distance of a gene with that of inter-cluster (https://en.wikipedia.org/wiki/Silhouette_(clustering)) Described originally in the paper: https://www.sciencedirect.com/science/article/pii/0377042787901257

# %%
# Rank cluster genes by silhouettes
ranked_clusters = {}
data_types = ['TC', 'TPM']
res_ids = ['CLUSTER_ALL_GENES_TRANSCRIPT_CELL', 'CLUSTER_ALL_GENES_TPM']

for data_type, res_id in zip(data_types, res_ids):
   
    c_data = pd.read_csv(os.path.join(
        os.getcwd(),f'Results/{res_id}/Processed_Data/clust_input.tsv_processed.tsv'),
                        sep='\t', index_col='Genes')
    
    ranked_clusters[data_type] = Dc.rankGenesWithinClusters(clusters[data_type], c_data)

# %%
# Prepare txt file to read in pandas
import re

def prepareKEGGtxtFile(path_to_file, output_path):
    """
    Prepare txt file containing strain-specific pathways
    to be read by pandas
    """
    file = open(path_to_file, 'r')
    lines = file.readlines()
    new_lines = ['KEGG ID\tPathway\n']
    
    for line in lines:
        dok = re.search('dok\d{5}', line).group(0)
        ko = dok.replace('dok', 'ko')
        pathway = line.split(dok)[1].replace('\n','').strip()
        new_line = f'{ko}\t{pathway}\n'
        new_lines.append(new_line)     
    
    file.close()
    new_file = open(output_path, 'w')
    new_file.writelines(new_lines)
    new_file.close()
    
prepareKEGGtxtFile('Data/Function_Annotations/KEGG/Dokdonia_KEGG_pathways.txt',
                   'Data/Function_Annotations/KEGG/new_Dokdonia_KEGG_pathways.txt')

# %%
# Need to find a way to delete entries in dict while iterating, the problem is that the list gets smaller so indices don't work.
def removeEmptySystems(kegg_pathways):
    """
    Remove empty systems from kegg pathways
    """
    for i, supersystem in list(enumerate(kegg_pathways)):
        systems_to_keep = []
        for system in supersystem['children']:
            if len(system['children']) > 0:
                systems_to_keep.append(system)
        kegg_pathways[i]['children'] = systems_to_keep
    return kegg_pathways
# Out:
# Pathway: "09113 Global maps only" without ko number

# %%
with open('Data/Function_Annotations/KEGG/Dokdonia_KEGG_pathways.json') as json_file:
    kegg_pathways = json.load(json_file)['children']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3fcb943dad78> in <module>
#       1 with open('Data/Function_Annotations/KEGG/Dokdonia_KEGG_pathways.json') as json_file:
# ----> 2     kegg_pathways = json.load(json_file)['children']
#
# TypeError: list indices must be integers or slices, not str

# %%
# Obtain KEGG pathways only for Dokdonia sp. MED134
def pruneKEGGpathwaysForStrain(path_to_ALL_KEGG, path_to_Strain_pathways, output_path):
    """
    Remove non Strain-specific KEGG entries from the KEGG pathway database.
    Data from KEGG entry: https://www.genome.jp/dbget-bin/www_bget?gn:T03275
    """
    Dokdonia_KEGG = pd.read_csv('Data/Function_Annotations/KEGG/new_Dokdonia_KEGG_pathways.txt', delimiter='\t')
    
    strain_kos = Dokdonia_KEGG['KEGG ID'].values

    with open('Data/Function_Annotations/KEGG/kegg_pathways.json') as json_file:
        kegg_pathways = json.load(json_file)['children']

    supersystems = ['09100 Metabolism', '09120 Genetic Information Processing',
                    '09130 Environmental Information Processing', '09140 Cellular Processes']

    strain_kegg_pathways = [supersystem for supersystem in kegg_pathways
                            if supersystem['name'] in supersystems]

    for i, supersystem in list(enumerate(strain_kegg_pathways)):
        for j, system in list(enumerate(supersystem['children'])):

            subsystems_to_keep = []
            for subsystem in system['children']:

                try:
                    ko_id = Dc.extractKoID(subsystem['name'])    
                    if ko_id in strain_kos:
                        subsystems_to_keep.append(subsystem)

                except Exception:
                    print(f'Pathway: "{subsystem["name"]}" without ko number')

                strain_kegg_pathways[i]['children'][j]['children'] = subsystems_to_keep

    strain_kegg_pathways = removeEmptySystems(strain_kegg_pathways)
    with open('Data/Function_Annotations/KEGG/Dokdonia_KEGG_pathways.json', 'w') as outfile:
        json.dump(strain_kegg_pathways, outfile)

# %%
strain_kegg_pathways = {'name': 'ko00001', 'children': strain_kegg_pathways}
# Out:
# [{'name': '09100 Metabolism',
#   'children': [{'name': '09101 Carbohydrate metabolism',
#     'children': [{'name': '00010 Glycolysis / Gluconeogenesis [PATH:ko00010]',
#       'children': [{'name': 'K00844  HK; hexokinase [EC:2.7.1.1]'},
#        {'name': 'K12407  GCK; glucokinase [EC:2.7.1.2]'},
#        {'name': 'K00845  glk; glucokinase [EC:2.7.1.2]'},
#        {'name': 'K01810  GPI, pgi; glucose-6-phosphate isomerase [EC:5.3.1.9]'},
#        {'name': 'K06859  pgi1; glucose-6-phosphate isomerase, archaeal [EC:5.3.1.9]'},
#        {'name': 'K13810  tal-pgi; transaldolase / glucose-6-phosphate isomerase [EC:2.2.1.2 5.3.1.9]'},
#        {'name': 'K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'},
#        {'name': 'K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]'},
#        {'name': 'K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]'},
#        {'name': 'K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]'},
#        {'name': 'K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]'},
#        {'name': 'K00918  pfkC; ADP-dependent phosphofructokinase/glucokinase [EC:2.7.1.146 2.7.1.147]'},
#        {'name': 'K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]'},
#        {'name': 'K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]'},
#        {'name': 'K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]'},
#        {'name': 'K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]'},
#        {'name': 'K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]'},
#        {'name': 'K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]'},
#        {'name': 'K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]'},
#        {'name': 'K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]'},
#        {'name': 'K01803  TPI, tpiA; triosephosphate isomerase (TIM) [EC:5.3.1.1]'},
#        {'name': 'K00134  GAPDH, gapA; glyceraldehyde 3-phosphate dehydrogenase [EC:1.2.1.12]'},
#        {'name': 'K10705  GAPDHS; glyceraldehyde-3-phosphate dehydrogenase, spermatogenic [EC:1.2.1.12]'},
#        {'name': 'K00150  gap2; glyceraldehyde-3-phosphate dehydrogenase (NAD(P)) [EC:1.2.1.59]'},
#        {'name': 'K00927  PGK, pgk; phosphoglycerate kinase [EC:2.7.2.3]'},
#        {'name': 'K01834  PGAM, gpmA; 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'},
#        {'name': 'K15634  gpmB; 2,3-bisphosphoglycerate-dependent phosphoglycerate mutase [EC:5.4.2.11]'},
#        {'name': 'K15633  gpmI; 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]'},
#        {'name': 'K15635  apgM; 2,3-bisphosphoglycerate-independent phosphoglycerate mutase [EC:5.4.2.12]'},
#        {'name': 'K01689  ENO, eno; enolase [EC:4.2.1.11]'},
#        {'name': 'K00873  PK, pyk; pyruvate kinase [EC:2.7.1.40]'},
#        {'name': 'K12406  PKLR; pyruvate kinase isozymes R/L [EC:2.7.1.40]'},
#        {'name': 'K01006  ppdK; pyruvate, orthophosphate dikinase [EC:2.7.9.1]'},
#        {'name': 'K01007  pps, ppsA; pyruvate, water dikinase [EC:2.7.9.2]'},
#        {'name': 'K00163  aceE; pyruvate dehydrogenase E1 component [EC:1.2.4.1]'},
#        {'name': 'K00161  PDHA, pdhA; pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]'},
#        {'name': 'K00162  PDHB, pdhB; pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]'},
#        {'name': 'K00627  DLAT, aceF, pdhC; pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'},
#        {'name': 'K00382  DLD, lpd, pdhD; dihydrolipoamide dehydrogenase [EC:1.8.1.4]'},
#        {'name': 'K13997  PDHX; dihydrolipoamide dehydrogenase-binding protein of pyruvate dehydrogenase complex'},
#        {'name': 'K00169  porA; pyruvate ferredoxin oxidoreductase alpha subunit [EC:1.2.7.1]'},
#        {'name': 'K00170  porB; pyruvate ferredoxin oxidoreductase beta subunit [EC:1.2.7.1]'},
#        {'name': 'K00172  porC, porG; pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.1]'},
#        {'name': 'K00189  vorG, porG; 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'},
#        {'name': 'K00171  porD; pyruvate ferredoxin oxidoreductase delta subunit [EC:1.2.7.1]'},
#        {'name': 'K03737  por, nifJ; pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]'},
#        {'name': 'K00174  korA, oorA, oforA; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11]'},
#        {'name': 'K00175  korB, oorB, oforB; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]'},
#        {'name': 'K00016  LDH, ldh; L-lactate dehydrogenase [EC:1.1.1.27]'},
#        {'name': 'K01568  PDC, pdc; pyruvate decarboxylase [EC:4.1.1.1]'},
#        {'name': 'K13951  ADH1_7; alcohol dehydrogenase 1/7 [EC:1.1.1.1]'},
#        {'name': 'K13980  ADH4; alcohol dehydrogenase 4 [EC:1.1.1.1]'},
#        {'name': 'K00121  frmA, ADH5, adhC; S-(hydroxymethyl)glutathione dehydrogenase / alcohol dehydrogenase [EC:1.1.1.284 1.1.1.1]'},
#        {'name': 'K13952  ADH6; alcohol dehydrogenase 6 [EC:1.1.1.1]'},
#        {'name': 'K04072  adhE; acetaldehyde dehydrogenase / alcohol dehydrogenase [EC:1.2.1.10 1.1.1.1]'},
#        {'name': 'K13953  adhP; alcohol dehydrogenase, propanol-preferring [EC:1.1.1.1]'},
#        {'name': 'K13954  yiaY; alcohol dehydrogenase [EC:1.1.1.1]'},
#        {'name': 'K18857  ADH1; alcohol dehydrogenase class-P [EC:1.1.1.1]'},
#        {'name': 'K00001  E1.1.1.1, adh; alcohol dehydrogenase [EC:1.1.1.1]'},
#        {'name': 'K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'},
#        {'name': 'K12957  ahr; alcohol/geraniol dehydrogenase (NADP+) [EC:1.1.1.2 1.1.1.183]'},
#        {'name': 'K13979  yahK; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'},
#        {'name': 'K14028  mdh1, mxaF; methanol dehydrogenase (cytochrome c) subunit 1 [EC:1.1.2.7]'},
#        {'name': 'K14029  mdh2, mxaI; methanol dehydrogenase (cytochrome c) subunit 2 [EC:1.1.2.7]'},
#        {'name': 'K00114  exaA; alcohol dehydrogenase (cytochrome c) [EC:1.1.2.8]'},
#        {'name': 'K04022  eutG; alcohol dehydrogenase'},
#        {'name': 'K22473  adhA; alcohol dehydrogenase (quinone), dehydrogenase subunit [EC:1.1.5.5]'},
#        {'name': 'K22474  adhB; alcohol dehydrogenase (quinone), cytochrome c subunit [EC:1.1.5.5]'},
#        {'name': 'K00128  ALDH; aldehyde dehydrogenase (NAD+) [EC:1.2.1.3]'},
#        {'name': 'K14085  ALDH7A1; aldehyde dehydrogenase family 7 member A1 [EC:1.2.1.31 1.2.1.8 1.2.1.3]'},
#        {'name': 'K00149  ALDH9A1; aldehyde dehydrogenase family 9 member A1 [EC:1.2.1.47 1.2.1.3]'},
#        {'name': 'K00129  ALDH3; aldehyde dehydrogenase (NAD(P)+) [EC:1.2.1.5]'},
#        {'name': 'K00138  aldB; aldehyde dehydrogenase [EC:1.2.1.-]'},
#        {'name': 'K01895  ACSS1_2, acs; acetyl-CoA synthetase [EC:6.2.1.1]'},
#        {'name': 'K01913  AAE7, ACN1; acetate/butyrate---CoA ligase [EC:6.2.1.1 6.2.1.2]'},
#        {'name': 'K01905  acdA; acetate---CoA ligase (ADP-forming) subunit alpha [EC:6.2.1.13]'},
#        {'name': 'K22224  acdB; acetate---CoA ligase (ADP-forming) subunit beta [EC:6.2.1.13]'},
#        {'name': 'K24012  acdAB; acetate---CoA ligase (ADP-forming) [EC:6.2.1.13]'},
#        {'name': 'K01785  galM, GALM; aldose 1-epimerase [EC:5.1.3.3]'},
#        {'name': 'K01085  agp; glucose-1-phosphatase [EC:3.1.3.10]'},
#        {'name': 'K20866  yihX; glucose-1-phosphatase [EC:3.1.3.10]'},
#        {'name': 'K01835  pgm; phosphoglucomutase [EC:5.4.2.2]'},
#        {'name': 'K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]'},
#        {'name': 'K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]'},
#        {'name': 'K01084  G6PC; glucose-6-phosphatase [EC:3.1.3.9]'},
#        {'name': 'K00886  ppgK; polyphosphate glucokinase [EC:2.7.1.63]'},
#        {'name': 'K08074  ADPGK; ADP-dependent glucokinase [EC:2.7.1.147]'},
#        {'name': 'K01792  E5.1.3.15; glucose-6-phosphate 1-epimerase [EC:5.1.3.15]'},
#        {'name': 'K01837  BPGM; bisphosphoglycerate/phosphoglycerate mutase [EC:5.4.2.4 5.4.2.11]'},
#        {'name': 'K03103  MINPP1; multiple inositol-polyphosphate phosphatase / 2,3-bisphosphoglycerate 3-phosphatase [EC:3.1.3.62 3.1.3.80]'},
#        {'name': 'K11389  gapor; glyceraldehyde-3-phosphate dehydrogenase (ferredoxin) [EC:1.2.7.6]'},
#        {'name': 'K00131  gapN; glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'},
#        {'name': 'K18978  gapN; glyceraldehyde-3-phosphate dehydrogenase [NAD(P)+] [EC:1.2.1.90]'},
#        {'name': 'K01596  E4.1.1.32, pckA, PCK; phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]'},
#        {'name': 'K01610  E4.1.1.49, pckA; phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]'},
#        {'name': 'K01222  E3.2.1.86A, celF; 6-phospho-beta-glucosidase [EC:3.2.1.86]'},
#        {'name': 'K01223  E3.2.1.86B, bglA; 6-phospho-beta-glucosidase [EC:3.2.1.86]'},
#        {'name': 'K02777  crr; sugar PTS system EIIA component [EC:2.7.1.-]'},
#        {'name': 'K02779  ptsG; glucose PTS system EIICB or EIICBA component [EC:2.7.1.199]'},
#        {'name': 'K02791  malX; maltose/glucose PTS system EIICB component [EC:2.7.1.199 2.7.1.208]'},
#        {'name': 'K20118  ptsG, glcA, glcB; glucose PTS system EIICBA or EIICB component [EC:2.7.1.199]'},
#        {'name': 'K02753  ascF; beta-glucoside (arbutin/salicin/cellobiose) PTS system EIICB component [EC:2.7.1.-]'}]},
#      {'name': '00020 Citrate cycle (TCA cycle) [PATH:ko00020]',
#       'children': [{'name': 'K01647  CS, gltA; citrate synthase [EC:2.3.3.1]'},
#        {'name': 'K01648  ACLY; ATP citrate (pro-S)-lyase [EC:2.3.3.8]'},
#        {'name': 'K15230  aclA; ATP-citrate lyase alpha-subunit [EC:2.3.3.8]'},
#        {'name': 'K15231  aclB; ATP-citrate lyase beta-subunit [EC:2.3.3.8]'},
#        {'name': 'K05942  E2.3.3.3; citrate (Re)-synthase [EC:2.3.3.3]'},
#        {'name': 'K01681  ACO, acnA; aconitate hydratase [EC:4.2.1.3]'},
#        {'name': 'K01682  acnB; aconitate hydratase 2 / 2-methylisocitrate dehydratase [EC:4.2.1.3 4.2.1.99]'},
#        {'name': 'K00031  IDH1, IDH2, icd; isocitrate dehydrogenase [EC:1.1.1.42]'},
#        {'name': 'K00030  IDH3; isocitrate dehydrogenase (NAD+) [EC:1.1.1.41]'},
#        {'name': 'K17753  HICDH; isocitrate--homoisocitrate dehydrogenase [EC:1.1.1.286]'},
#        {'name': 'K00164  OGDH, sucA; 2-oxoglutarate dehydrogenase E1 component [EC:1.2.4.2]'},
#        {'name': 'K00658  DLST, sucB; 2-oxoglutarate dehydrogenase E2 component (dihydrolipoamide succinyltransferase) [EC:2.3.1.61]'},
#        {'name': 'K01616  kgd; multifunctional 2-oxoglutarate metabolism enzyme [EC:2.2.1.5 4.1.1.71 1.2.4.2 2.3.1.61]'},
#        {'name': 'K00382  DLD, lpd, pdhD; dihydrolipoamide dehydrogenase [EC:1.8.1.4]'},
#        {'name': 'K00174  korA, oorA, oforA; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit alpha [EC:1.2.7.3 1.2.7.11]'},
#        {'name': 'K00175  korB, oorB, oforB; 2-oxoglutarate/2-oxoacid ferredoxin oxidoreductase subunit beta [EC:1.2.7.3 1.2.7.11]'},
#        {'name': 'K00177  korC, oorC; 2-oxoglutarate ferredoxin oxidoreductase subunit gamma [EC:1.2.7.3]'},
#        {'name': 'K00176  korD, oorD; 2-oxoglutarate ferredoxin oxidoreductase subunit delta [EC:1.2.7.3]'},
#        {'name': 'K01902  sucD; succinyl-CoA synthetase alpha subunit [EC:6.2.1.5]'},
#        {'name': 'K01903  sucC; succinyl-CoA synthetase beta subunit [EC:6.2.1.5]'},
#        {'name': 'K01899  LSC1; succinyl-CoA synthetase alpha subunit [EC:6.2.1.4 6.2.1.5]'},
#        {'name': 'K01900  LSC2; succinyl-CoA synthetase beta subunit [EC:6.2.1.4 6.2.1.5]'},
#        {'name': 'K18118  aarC, cat1; succinyl-CoA:acetate CoA-transferase [EC:2.8.3.18]'},
#        {'name': 'K00234  SDHA, SDH1; succinate dehydrogenase (ubiquinone) flavoprotein subunit [EC:1.3.5.1]'},
#        {'name': 'K00235  SDHB, SDH2; succinate dehydrogenase (ubiquinone) iron-sulfur subunit [EC:1.3.5.1]'},
#        {'name': 'K00236  SDHC, SDH3; succinate dehydrogenase (ubiquinone) cytochrome b560 subunit'},
#        {'name': 'K00237  SDHD, SDH4; succinate dehydrogenase (ubiquinone) membrane anchor subunit'},
#        {'name': 'K00239  sdhA, frdA; succinate dehydrogenase / fumarate reductase, flavoprotein subunit [EC:1.3.5.1 1.3.5.4]'},
#        {'name': 'K00240  sdhB, frdB; succinate dehydrogenase / fumarate reductase, iron-sulfur subunit [EC:1.3.5.1 1.3.5.4]'},
#        {'name': 'K00241  sdhC, frdC; succinate dehydrogenase / fumarate reductase, cytochrome b subunit'},
#        {'name': 'K00242  sdhD, frdD; succinate dehydrogenase / fumarate reductase, membrane anchor subunit'},
#        {'name': 'K18859  sdhD, frdD; succinate dehydrogenase / fumarate reductase, subunit D'},
#        {'name': 'K18860  sdhD, frdD; putative succinate dehydrogenase / fumarate reductase, subunit D'},
#        {'name': 'K00244  frdA; fumarate reductase flavoprotein subunit [EC:1.3.5.4]'},
#        {'name': 'K00245  frdB; fumarate reductase iron-sulfur subunit [EC:1.3.5.4]'},
#        {'name': 'K00246  frdC; fumarate reductase subunit C'},
#        {'name': 'K00247  frdD; fumarate reductase subunit D'},
#        {'name': 'K01676  E4.2.1.2A, fumA, fumB; fumarate hydratase, class I [EC:4.2.1.2]'},
#        {'name': 'K01677  E4.2.1.2AA, fumA; fumarate hydratase subunit alpha [EC:4.2.1.2]'},
#        {'name': 'K01678  E4.2.1.2AB, fumB; fumarate hydratase subunit beta [EC:4.2.1.2]'},
#        {'name': 'K01679  E4.2.1.2B, fumC, FH; fumarate hydratase, class II [EC:4.2.1.2]'},
#        {'name': 'K01675  fumD; fumarate hydratase D [EC:4.2.1.2]'},
#        {'name': 'K01774  fumE; fumarate hydratase E [EC:4.2.1.2]'},
#        {'name': 'K00025  MDH1; malate dehydrogenase [EC:1.1.1.37]'},
#        {'name': 'K00026  MDH2; malate dehydrogenase [EC:1.1.1.37]'},
#        {'name': 'K00024  mdh; malate dehydrogenase [EC:1.1.1.37]'},
#        {'name': 'K00116  mqo; malate dehydrogenase (quinone) [EC:1.1.5.4]'},
#        {'name': 'K01958  PC, pyc; pyruvate carboxylase [EC:6.4.1.1]'},
#        {'name': 'K01959  pycA; pyruvate carboxylase subunit A [EC:6.4.1.1]'},
#        {'name': 'K01960  pycB; pyruvate carboxylase subunit B [EC:6.4.1.1]'},
#        {'name': 'K01610  E4.1.1.49, pckA; phosphoenolpyruvate carboxykinase (ATP) [EC:4.1.1.49]'},
#        {'name': 'K01596  E4.1.1.32, pckA, PCK; phosphoenolpyruvate carboxykinase (GTP) [EC:4.1.1.32]'},
#        {'name': 'K00163  aceE; pyruvate dehydrogenase E1 component [EC:1.2.4.1]'},
#        {'name': 'K00161  PDHA, pdhA; pyruvate dehydrogenase E1 component alpha subunit [EC:1.2.4.1]'},
#        {'name': 'K00162  PDHB, pdhB; pyruvate dehydrogenase E1 component beta subunit [EC:1.2.4.1]'},
#        {'name': 'K00627  DLAT, aceF, pdhC; pyruvate dehydrogenase E2 component (dihydrolipoamide acetyltransferase) [EC:2.3.1.12]'},
#        {'name': 'K13997  PDHX; dihydrolipoamide dehydrogenase-binding protein of pyruvate dehydrogenase complex'},
#        {'name': 'K00169  porA; pyruvate ferredoxin oxidoreductase alpha subunit [EC:1.2.7.1]'},
#        {'name': 'K00170  porB; pyruvate ferredoxin oxidoreductase beta subunit [EC:1.2.7.1]'},
#        {'name': 'K00172  porC, porG; pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.1]'},
#        {'name': 'K00189  vorG, porG; 2-oxoisovalerate/pyruvate ferredoxin oxidoreductase gamma subunit [EC:1.2.7.7 1.2.7.1]'},
#        {'name': 'K00171  porD; pyruvate ferredoxin oxidoreductase delta subunit [EC:1.2.7.1]'},
#        {'name': 'K03737  por, nifJ; pyruvate-ferredoxin/flavodoxin oxidoreductase [EC:1.2.7.1 1.2.7.-]'}]},
#      {'name': '00030 Pentose phosphate pathway [PATH:ko00030]',
#       'children': [{'name': 'K01810  GPI, pgi; glucose-6-phosphate isomerase [EC:5.3.1.9]'},
#        {'name': 'K06859  pgi1; glucose-6-phosphate isomerase, archaeal [EC:5.3.1.9]'},
#        {'name': 'K13810  tal-pgi; transaldolase / glucose-6-phosphate isomerase [EC:2.2.1.2 5.3.1.9]'},
#        {'name': 'K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'},
#        {'name': 'K00036  G6PD, zwf; glucose-6-phosphate 1-dehydrogenase [EC:1.1.1.49 1.1.1.363]'},
#        {'name': 'K19243  azf; NAD+ dependent glucose-6-phosphate dehydrogenase [EC:1.1.1.388]'},
#        {'name': 'K01057  PGLS, pgl, devB; 6-phosphogluconolactonase [EC:3.1.1.31]'},
#        {'name': 'K07404  pgl; 6-phosphogluconolactonase [EC:3.1.1.31]'},
#        {'name': 'K13937  H6PD; hexose-6-phosphate dehydrogenase [EC:1.1.1.47 3.1.1.31]'},
#        {'name': 'K00033  PGD, gnd, gntZ; 6-phosphogluconate dehydrogenase [EC:1.1.1.44 1.1.1.343]'},
#        {'name': 'K01783  rpe, RPE; ribulose-phosphate 3-epimerase [EC:5.1.3.1]'},
#        {'name': 'K00615  E2.2.1.1, tktA, tktB; transketolase [EC:2.2.1.1]'},
#        {'name': 'K00616  E2.2.1.2, talA, talB; transaldolase [EC:2.2.1.2]'},
#        {'name': 'K01807  rpiA; ribose 5-phosphate isomerase A [EC:5.3.1.6]'},
#        {'name': 'K01808  rpiB; ribose 5-phosphate isomerase B [EC:5.3.1.6]'},
#        {'name': 'K13812  fae-hps; bifunctional enzyme Fae/Hps [EC:4.2.1.147 4.1.2.43]'},
#        {'name': 'K08093  hxlA; 3-hexulose-6-phosphate synthase [EC:4.1.2.43]'},
#        {'name': 'K08094  hxlB; 6-phospho-3-hexuloisomerase [EC:5.3.1.27]'},
#        {'name': 'K13831  hps-phi; 3-hexulose-6-phosphate synthase / 6-phospho-3-hexuloisomerase [EC:4.1.2.43 5.3.1.27]'},
#        {'name': 'K01621  xfp, xpk; xylulose-5-phosphate/fructose-6-phosphate phosphoketolase [EC:4.1.2.9 4.1.2.22]'},
#        {'name': 'K01619  deoC, DERA; deoxyribose-phosphate aldolase [EC:4.1.2.4]'},
#        {'name': 'K00852  rbsK, RBKS; ribokinase [EC:2.7.1.15]'},
#        {'name': 'K01839  deoB; phosphopentomutase [EC:5.4.2.7]'},
#        {'name': 'K22199  ppm; phosphopentomutase [EC:5.4.2.7]'},
#        {'name': 'K01835  pgm; phosphoglucomutase [EC:5.4.2.2]'},
#        {'name': 'K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]'},
#        {'name': 'K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]'},
#        {'name': 'K05774  phnN; ribose 1,5-bisphosphokinase [EC:2.7.4.23]'},
#        {'name': 'K00948  PRPS, prsA; ribose-phosphate pyrophosphokinase [EC:2.7.6.1]'},
#        {'name': 'K01690  edd; phosphogluconate dehydratase [EC:4.2.1.12]'},
#        {'name': 'K01625  eda; 2-dehydro-3-deoxyphosphogluconate aldolase / (4S)-4-hydroxy-2-oxoglutarate aldolase [EC:4.1.2.14 4.1.3.42]'},
#        {'name': 'K17463  dgaF; 2-dehydro-3-deoxy-phosphogluconate aldolase [EC:4.1.2.14]'},
#        {'name': 'K11395  kdpgA; 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55]'},
#        {'name': 'K00131  gapN; glyceraldehyde-3-phosphate dehydrogenase (NADP+) [EC:1.2.1.9]'},
#        {'name': 'K18978  gapN; glyceraldehyde-3-phosphate dehydrogenase [NAD(P)+] [EC:1.2.1.90]'},
#        {'name': 'K00034  gdh; glucose 1-dehydrogenase [EC:1.1.1.47]'},
#        {'name': 'K22969  gdh; glucose 1-dehydrogenase [EC:1.1.1.47]'},
#        {'name': 'K21840  HOX; hexose oxidase [EC:1.1.3.5]'},
#        {'name': 'K18124  gdh2, gdhA; glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360]'},
#        {'name': 'K18125  ssgdh; aldose 1-dehydrogenase [NAD(P)+] [EC:1.1.1.359]'},
#        {'name': 'K00115  GLD; glucose 1-dehydrogenase (FAD, quinone) [EC:1.1.5.9]'},
#        {'name': 'K19813  gdh; glucose dehydrogenase [EC:1.1.5.9]'},
#        {'name': 'K00117  gcd; quinoprotein glucose dehydrogenase [EC:1.1.5.2]'},
#        {'name': 'K01053  gnl, RGN; gluconolactonase [EC:3.1.1.17]'},
#        {'name': 'K06151  E1.1.99.3A; gluconate 2-dehydrogenase alpha chain [EC:1.1.99.3]'},
#        {'name': 'K06152  E1.1.99.3G; gluconate 2-dehydrogenase gamma chain [EC:1.1.99.3]'},
#        {'name': 'K00090  ghrB; glyoxylate/hydroxypyruvate/2-ketogluconate reductase [EC:1.1.1.79 1.1.1.81 1.1.1.215]'},
#        {'name': 'K22229  K22229; 2-ketogluconate reductase [EC:1.1.1.215]'},
#        {'name': 'K11441  kguK; dehydrogluconokinase [EC:2.7.1.13]'},
#        {'name': 'K00032  E1.1.1.43; phosphogluconate 2-dehydrogenase [EC:1.1.1.43]'},
#        {'name': 'K00851  E2.7.1.12, gntK, idnK; gluconokinase [EC:2.7.1.12]'},
#        {'name': 'K05308  gnaD; gluconate/galactonate dehydratase [EC:4.2.1.140]'},
#        {'name': 'K00874  kdgK; 2-dehydro-3-deoxygluconokinase [EC:2.7.1.45]'},
#        {'name': 'K18126  sskdgK; 2-dehydro-3-deoxygluconokinase / 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.178]'},
#        {'name': 'K18127  kdgA; 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51]'},
#        {'name': 'K03738  aor; aldehyde:ferredoxin oxidoreductase [EC:1.2.7.5]'},
#        {'name': 'K18020  cutA; glyceraldehyde dehydrogenase large subunit [EC:1.2.99.8]'},
#        {'name': 'K18021  cutB; glyceraldehyde dehydrogenase medium subunit [EC:1.2.99.8]'},
#        {'name': 'K18022  cutC; glyceraldehyde dehydrogenase small subunit [EC:1.2.99.8]'},
#        {'name': 'K18128  gadh; D-glyceraldehyde dehydrogenase (NADP+) [EC:1.2.1.89]'},
#        {'name': 'K11529  gck, gckA, GLYCTK; glycerate 2-kinase [EC:2.7.1.165]'},
#        {'name': 'K22345  E4.3.1.9; glucosaminate ammonia-lyase [EC:4.3.1.9]'},
#        {'name': 'K17464  dgaA; D-glucosaminate PTS system EIIA component [EC:2.7.1.203]'},
#        {'name': 'K17465  dgaB; D-glucosaminate PTS system EIIB component [EC:2.7.1.203]'},
#        {'name': 'K17466  dgaC; D-glucosaminate PTS system EIIC component'},
#        {'name': 'K17467  dgaD; D-glucosaminate PTS system EIID component'},
#        {'name': 'K17468  dgaE; D-glucosaminate-6-phosphate ammonia-lyase [EC:4.3.1.29]'},
#        {'name': 'K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]'},
#        {'name': 'K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]'},
#        {'name': 'K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]'},
#        {'name': 'K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]'},
#        {'name': 'K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]'},
#        {'name': 'K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]'},
#        {'name': 'K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]'},
#        {'name': 'K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]'},
#        {'name': 'K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]'},
#        {'name': 'K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]'},
#        {'name': 'K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]'},
#        {'name': 'K00918  pfkC; ADP-dependent phosphofructokinase/glucokinase [EC:2.7.1.146 2.7.1.147]'},
#        {'name': 'K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]'}]},
#      {'name': '00040 Pentose and glucuronate interconversions [PATH:ko00040]',
#       'children': [{'name': 'K01051  E3.1.1.11; pectinesterase [EC:3.1.1.11]'},
#        {'name': 'K22539  PLY; pectate lyase [EC:4.2.2.2]'},
#        {'name': 'K01728  pel; pectate lyase [EC:4.2.2.2]'},
#        {'name': 'K19551  pelC; pectate lyase C [EC:4.2.2.2 4.2.2.10]'},
#        {'name': 'K01731  pelW; pectate disaccharide-lyase [EC:4.2.2.9]'},
#        {'name': 'K22994  pelX; pectate disaccharide-lyase [EC:4.2.2.9]'},
#        {'name': 'K01730  ogl; oligogalacturonide lyase [EC:4.2.2.6]'},
#        {'name': 'K01815  kduI; 4-deoxy-L-threo-5-hexosulose-uronate ketol-isomerase [EC:5.3.1.17]'},
#        {'name': 'K00065  kduD; 2-dehydro-3-deoxy-D-gluconate 5-dehydrogenase [EC:1.1.1.127]'},
#        {'name': 'K01184  E3.2.1.15; polygalacturonase [EC:3.2.1.15]'},
#        {'name': 'K01213  E3.2.1.67; galacturan 1,4-alpha-galacturonidase [EC:3.2.1.67]'},
#        {'name': 'K22933  lplD; galacturan 1,4-alpha-galacturonidase [EC:3.2.1.67]'},
#        {'name': 'K01812  uxaC; glucuronate isomerase [EC:5.3.1.12]'},
#        {'name': 'K00041  uxaB; tagaturonate reductase [EC:1.1.1.58]'},
#        {'name': 'K01685  uxaA; altronate hydrolase [EC:4.2.1.7]'},
#        {'name': 'K16849  uxaA1; altronate dehydratase small subunit [EC:4.2.1.7]'},
#        {'name': 'K16850  uxaA2; altronate dehydratase large subunit [EC:4.2.1.7]'},
#        {'name': 'K01686  uxuA; mannonate dehydratase [EC:4.2.1.8]'},
#        {'name': 'K08323  rspA, manD; mannonate dehydratase [EC:4.2.1.8]'},
#        {'name': 'K08322  rspB; L-gulonate 5-dehydrogenase [EC:1.1.1.380]'},
#        {'name': 'K00040  uxuB; fructuronate reductase [EC:1.1.1.57]'},
#        {'name': 'K21619  uxaE; tagaturonate epimerase [EC:5.1.2.7]'},
#        {'name': 'K18106  GAAA; D-galacturonate reductase [EC:1.1.1.-]'},
#        {'name': 'K19634  gar1; D-galacturonate reductase [EC:1.1.1.365]'},
#        {'name': 'K18102  GAAB, LGD1; L-galactonate dehydratase [EC:4.2.1.146]'},
#        {'name': 'K18103  GAAC, LGA1; L-threo-3-deoxy-hexylosonate aldolase [EC:4.1.2.54]'},
#        {'name': 'K18107  GAAD; L-glyceraldehyde reductase [EC:1.1.1.372]'},
#        {'name': 'K01195  uidA, GUSB; beta-glucuronidase [EC:3.2.1.31]'},
#        {'name': 'K14756  KL; klotho [EC:3.2.1.31]'},
#        {'name': 'K00699  UGT; glucuronosyltransferase [EC:2.4.1.17]'},
#        {'name': 'K16190  GLCAK; glucuronokinase [EC:2.7.1.43]'},
#        {'name': 'K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]'},
#        {'name': 'K00012  UGDH, ugd; UDPglucose 6-dehydrogenase [EC:1.1.1.22]'},
#        {'name': 'K00963  UGP2, galU, galF; UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]'},
#        {'name': 'K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'},
#        {'name': 'K13247  CRYL1; L-gulonate 3-dehydrogenase [EC:1.1.1.45]'},
#        {'name': 'K08092  dlgD; 3-dehydro-L-gulonate 2-dehydrogenase [EC:1.1.1.130]'},
#        {'name': 'K00880  lyxK; L-xylulokinase [EC:2.7.1.53]'},
#        {'name': 'K03078  ulaD, sgaH, sgbH; 3-dehydro-L-gulonate-6-phosphate decarboxylase [EC:4.1.1.85]'},
#        {'name': 'K03079  ulaE, sgaU, sgbU; L-ribulose-5-phosphate 3-epimerase [EC:5.1.3.22]'},
#        {'name': 'K03077  araD, ulaF, sgaE, sgbE; L-ribulose-5-phosphate 4-epimerase [EC:5.1.3.4]'},
#        {'name': 'K01783  rpe, RPE; ribulose-phosphate 3-epimerase [EC:5.1.3.1]'},
#        {'name': 'K01804  araA; L-arabinose isomerase [EC:5.3.1.4]'},
#        {'name': 'K00853  araB; L-ribulokinase [EC:2.7.1.16]'},
#        {'name': 'K24707  E2.7.1.16; ribulokinase [EC:2.7.1.16]'},
#        {'name': 'K00854  xylB, XYLB; xylulokinase [EC:2.7.1.17]'},
#        {'name': 'K01805  xylA; xylose isomerase [EC:5.3.1.5]'},
#        {'name': 'K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]'},
#        {'name': 'K00594  xyoA, aldO; alditol oxidase [EC:1.1.3.41]'},
#        {'name': 'K17743  XR; D-xylose reductase [EC:1.1.1.307]'},
#        {'name': 'K03331  DCXR; L-xylulose reductase [EC:1.1.1.10]'},
#        {'name': 'K01820  rhaA; L-rhamnose isomerase / sugar isomerase [EC:5.3.1.14 5.3.1.-]'},
#        {'name': 'K00848  rhaB; rhamnulokinase [EC:2.7.1.5]'},
#        {'name': 'K01629  rhaD; rhamnulose-1-phosphate aldolase [EC:4.1.2.19]'},
#        {'name': 'K17738  ARD; D-arabinitol 2-dehydrogenase [EC:1.1.1.250]'},
#        {'name': 'K17818  ARD1; D-arabinitol dehydrogenase (NADP+) [EC:1.1.1.287]'},
#        {'name': 'K00007  dalD; D-arabinitol 4-dehydrogenase [EC:1.1.1.11]'},
#        {'name': 'K09988  lyxA; D-lyxose ketol-isomerase [EC:5.3.1.15]'},
#        {'name': 'K05351  E1.1.1.9; D-xylulose reductase [EC:1.1.1.9]'},
#        {'name': 'K00008  SORD, gutB; L-iditol 2-dehydrogenase [EC:1.1.1.14]'},
#        {'name': 'K22185  xylB; D-xylose 1-dehydrogenase [EC:1.1.1.175]'},
#        {'name': 'K00078  DHDH; dihydrodiol dehydrogenase / D-xylose 1-dehydrogenase (NADP) [EC:1.3.1.20 1.1.1.179]'},
#        {'name': 'K14273  xdh; D-xylose 1-dehydrogenase (NADP+, D-xylono-1,5-lactone-forming) [EC:1.1.1.179]'},
#        {'name': 'K14274  xylC; xylono-1,5-lactonase [EC:3.1.1.110]'},
#        {'name': 'K24442  xacA; D-xylose 1-dehydrogenase (NADP+, D-xylono-1,4-lactone-forming) [EC:1.1.1.424]'},
#        {'name': 'K24443  xacC; D-xylono/L-arabinono-1,4-lactonase [EC:3.1.1.68 3.1.1.15]'},
#        {'name': 'K14275  xad; D-xylonate dehydratase [EC:4.2.1.82]'},
#        {'name': 'K22186  xylD; xylonate dehydratase [EC:4.2.1.82]'},
#        {'name': 'K22396  yjhG, yagF; xylonate dehydratase [EC:4.2.1.82]'},
#        {'name': 'K22397  yjhH, yagE; 2-dehydro-3-deoxy-D-pentonate aldolase [EC:4.1.2.28]'},
#        {'name': 'K14259  kdaD, xacE, kdxD; 2-dehydro-3-deoxy-D-arabinonate dehydratase [EC:4.2.1.141]'},
#        {'name': 'K13877  aldH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]'},
#        {'name': 'K19588  dopDH; 2,5-dioxopentanoate dehydrogenase [EC:1.2.1.26]'},
#        {'name': 'K22187  xylA; alpha-ketoglutaric semialdehyde dehydrogenase [EC:1.2.1.-]'},
#        {'name': 'K00875  rbtK; D-ribulokinase [EC:2.7.1.47]'},
#        {'name': 'K22935  XK1, psk; D-ribulokinase [EC:2.7.1.47]'},
#        {'name': 'K00039  rbtD; ribitol 2-dehydrogenase [EC:1.1.1.56]'},
#        {'name': 'K21680  E1.1.1.137; ribulose-5-phosphate 2-dehydrogenase [EC:1.1.1.137]'},
#        {'name': 'K05352  tarJ; ribitol-5-phosphate 2-dehydrogenase (NADP+) [EC:1.1.1.405]'},
#        {'name': 'K21681  bcs1; ribitol-5-phosphate 2-dehydrogenase (NADP+) / D-ribitol-5-phosphate cytidylyltransferase [EC:1.1.1.405 2.7.7.40]'},
#        {'name': 'K21030  tarI; D-ribitol-5-phosphate cytidylyltransferase [EC:2.7.7.40]'},
#        {'name': 'K21031  ISPD; D-ribitol-5-phosphate cytidylyltransferase [EC:2.7.7.40]'},
#        {'name': 'K01818  fucI; L-fucose/D-arabinose isomerase [EC:5.3.1.25 5.3.1.3]'},
#        {'name': 'K00879  fucK; L-fuculokinase [EC:2.7.1.51]'},
#        {'name': 'K01628  fucA; L-fuculose-phosphate aldolase [EC:4.1.2.17]'}]},
#      {'name': '00051 Fructose and mannose metabolism [PATH:ko00051]',
#       'children': [{'name': 'K01218  gmuG; mannan endo-1,4-beta-mannosidase [EC:3.2.1.78]'},
#        {'name': 'K19355  MAN; mannan endo-1,4-beta-mannosidase [EC:3.2.1.78]'},
#        {'name': 'K00847  E2.7.1.4, scrK; fructokinase [EC:2.7.1.4]'},
#        {'name': 'K01809  manA, MPI; mannose-6-phosphate isomerase [EC:5.3.1.8]'},
#        {'name': 'K15916  pgi-pmi; glucose/mannose-6-phosphate isomerase [EC:5.3.1.9 5.3.1.8]'},
#        {'name': 'K16011  algA, xanB, rfbA, wbpW, pslB; mannose-1-phosphate guanylyltransferase / mannose-6-phosphate isomerase [EC:2.7.7.13 5.3.1.8]'},
#        {'name': 'K17497  PMM; phosphomannomutase [EC:5.4.2.8]'},
#        {'name': 'K01840  manB; phosphomannomutase [EC:5.4.2.8]'},
#        {'name': 'K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]'},
#        {'name': 'K16881  K16881; mannose-1-phosphate guanylyltransferase / phosphomannomutase [EC:2.7.7.13 5.4.2.8]'},
#        {'name': 'K00971  manC, cpsB; mannose-1-phosphate guanylyltransferase [EC:2.7.7.13]'},
#        {'name': 'K00966  GMPP; mannose-1-phosphate guanylyltransferase [EC:2.7.7.13]'},
#        {'name': 'K01711  gmd, GMDS; GDPmannose 4,6-dehydratase [EC:4.2.1.47]'},
#        {'name': 'K02377  TSTA3, fcl; GDP-L-fucose synthase [EC:1.1.1.271]'},
#        {'name': 'K00976  FPGT; fucose-1-phosphate guanylyltransferase [EC:2.7.7.30]'},
#        {'name': 'K18447  NUDX14; ADP-sugar diphosphatase [EC:3.6.1.21]'},
#        {'name': 'K05305  FUK; fucokinase [EC:2.7.1.52]'},
#        {'name': 'K01818  fucI; L-fucose/D-arabinose isomerase [EC:5.3.1.25 5.3.1.3]'},
#        {'name': 'K00879  fucK; L-fuculokinase [EC:2.7.1.51]'},
#        {'name': 'K01628  fucA; L-fuculose-phosphate aldolase [EC:4.1.2.17]'},
#        {'name': 'K00064  E1.1.1.122; D-threo-aldose 1-dehydrogenase [EC:1.1.1.122]'},
#        {'name': 'K18333  K18333; L-fucose dehydrogenase'},
#        {'name': 'K07046  K07046; L-fuconolactonase [EC:3.1.1.-]'},
#        {'name': 'K18334  fucD; L-fuconate dehydratase [EC:4.2.1.68]'},
#        {'name': 'K18335  K18335; 2-keto-3-deoxy-L-fuconate dehydrogenase [EC:1.1.1.-]'},
#        {'name': 'K18336  lra6; 2,4-didehydro-3-deoxy-L-rhamnonate hydrolase [EC:3.7.1.26]'},
#        {'name': 'K18337  LRA1; L-rhamnose 1-dehydrogenase [EC:1.1.1.378 1.1.1.377 1.1.1.173]'},
#        {'name': 'K18338  LRA2; L-rhamnono-1,4-lactonase [EC:3.1.1.65]'},
#        {'name': 'K12661  LRA3, rhmD; L-rhamnonate dehydratase [EC:4.2.1.90]'},
#        {'name': 'K18339  LRA4; 2-keto-3-deoxy-L-rhamnonate aldolase [EC:4.1.2.53]'},
#        {'name': 'K12660  rhmA; 2-dehydro-3-deoxy-L-rhamnonate aldolase [EC:4.1.2.53]'},
#        {'name': 'K01813  rhaA; L-rhamnose isomerase [EC:5.3.1.14]'},
#        {'name': 'K21883  lra5; 2-dehydro-3-deoxy-L-rhamnonate dehydrogenase (NAD+) [EC:1.1.1.401]'},
#        {'name': 'K01820  rhaA; L-rhamnose isomerase / sugar isomerase [EC:5.3.1.14 5.3.1.-]'},
#        {'name': 'K00848  rhaB; rhamnulokinase [EC:2.7.1.5]'},
#        {'name': 'K01629  rhaD; rhamnulose-1-phosphate aldolase [EC:4.1.2.19]'},
#        {'name': 'K05947  E2.4.1.217; mannosyl-3-phosphoglycerate synthase [EC:2.4.1.217]'},
#        {'name': 'K07026  E3.1.3.70; mannosyl-3-phosphoglycerate phosphatase [EC:3.1.3.70]'},
#        {'name': 'K18818  mgs; mannosylglycerate synthase [EC:2.4.1.269]'},
#        {'name': 'K00844  HK; hexokinase [EC:2.7.1.1]'},
#        {'name': 'K24182  PFK9; 6-phosphofructokinase [EC:2.7.1.11]'},
#        {'name': 'K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]'},
#        {'name': 'K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]'},
#        {'name': 'K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]'},
#        {'name': 'K00895  pfp, PFP; diphosphate-dependent phosphofructokinase [EC:2.7.1.90]'},
#        {'name': 'K03841  FBP, fbp; fructose-1,6-bisphosphatase I [EC:3.1.3.11]'},
#        {'name': 'K02446  glpX; fructose-1,6-bisphosphatase II [EC:3.1.3.11]'},
#        {'name': 'K11532  glpX-SEBP; fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K01086  fbp-SEBP; fructose-1,6-bisphosphatase I / sedoheptulose-1,7-bisphosphatase [EC:3.1.3.11 3.1.3.37]'},
#        {'name': 'K04041  fbp3; fructose-1,6-bisphosphatase III [EC:3.1.3.11]'},
#        {'name': 'K19028  PFKFB1; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 1 [EC:2.7.1.105 3.1.3.46]'},
#        {'name': 'K19029  PFKFB2; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 2 [EC:2.7.1.105 3.1.3.46]'},
#        {'name': 'K01103  PFKFB3; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 3 [EC:2.7.1.105 3.1.3.46]'},
#        {'name': 'K19030  PFKFB4; 6-phosphofructo-2-kinase / fructose-2,6-biphosphatase 4 [EC:2.7.1.105 3.1.3.46]'},
#        {'name': 'K00900  E2.7.1.105, PFK; 6-phosphofructo-2-kinase [EC:2.7.1.105]'},
#        {'name': 'K14634  TIGAR; fructose-2,6-bisphosphatase [EC:3.1.3.46]'},
#        {'name': 'K00009  mtlD; mannitol-1-phosphate 5-dehydrogenase [EC:1.1.1.17]'},
#        {'name': 'K00068  srlD; sorbitol-6-phosphate 2-dehydrogenase [EC:1.1.1.140]'},
#        {'name': 'K19956  sorE; L-sorbose 1-phosphate reductase [EC:1.1.1.-]'},
#        {'name': 'K00846  KHK; ketohexokinase [EC:2.7.1.3]'},
#        {'name': 'K00882  fruK; 1-phosphofructokinase [EC:2.7.1.56]'},
#        {'name': 'K00008  SORD, gutB; L-iditol 2-dehydrogenase [EC:1.1.1.14]'},
#        {'name': 'K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]'},
#        {'name': 'K00594  xyoA, aldO; alditol oxidase [EC:1.1.3.41]'},
#        {'name': 'K01805  xylA; xylose isomerase [EC:5.3.1.5]'},
#        {'name': 'K08261  E1.1.99.21; D-sorbitol dehydrogenase (acceptor) [EC:1.1.99.21]'},
#        {'name': 'K17742  SOU1; sorbose reductase [EC:1.1.1.289]'},
#        {'name': 'K19633  sr; sorbose reductase [EC:1.1.1.289]'},
#        {'name': 'K00045  E1.1.1.67, mtlK; mannitol 2-dehydrogenase [EC:1.1.1.67]'},
#        {'name': 'K00007  dalD; D-arabinitol 4-dehydrogenase [EC:1.1.1.11]'},
#        {'name': 'K00066  algD; GDP-mannose 6-dehydrogenase [EC:1.1.1.132]'},
#        {'name': 'K19290  alg8; mannuronan synthase [EC:2.4.1.33]'},
#        {'name': 'K19291  alg44; mannuronan synthase [EC:2.4.1.33]'},
#        {'name': 'K01795  algG; mannuronan 5-epimerase [EC:5.1.3.37]'},
#        {'name': 'K01729  algL; poly(beta-D-mannuronate) lyase [EC:4.2.2.3]'},
#        {'name': 'K01623  ALDO; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K11645  fbaB; fructose-bisphosphate aldolase, class I [EC:4.1.2.13]'},
#        {'name': 'K01624  FBA, fbaA; fructose-bisphosphate aldolase, class II [EC:4.1.2.13]'},
#        {'name': 'K01622  K01622; fructose 1,6-bisphosphate aldolase/phosphatase [EC:4.1.2.13 3.1.3.11]'},
#        {'name': 'K16305  K16305; fructose-bisphosphate aldolase / 6-deoxy-5-ketofructose 1-phosphate synthase [EC:4.1.2.13 2.2.1.11]'},
#        {'name': 'K16306  K16306; fructose-bisphosphate aldolase / 2-amino-3,7-dideoxy-D-threo-hept-6-ulosonate synthase [EC:4.1.2.13 2.2.1.10]'},
#        {'name': 'K01803  TPI, tpiA; triosephosphate isomerase (TIM) [EC:5.3.1.1]'},
#        {'name': 'K00863  DAK, TKFC; triose/dihydroxyacetone kinase / FAD-AMP lyase (cyclizing) [EC:2.7.1.28 2.7.1.29 4.6.1.15]'},
#        {'name': 'K03332  fruA; fructan beta-fructosidase [EC:3.2.1.80]'},
#        {'name': 'K22252  tld; GDP-6-deoxy-D-talose 4-dehydrogenase [EC:1.1.1.135]'},
#        {'name': 'K15856  rmd; GDP-4-dehydro-6-deoxy-D-mannose reductase [EC:1.1.1.281]'},
#        {'name': 'K00881  alsK; allose kinase [EC:2.7.1.55]'},
#        {'name': 'K01808  rpiB; ribose 5-phosphate isomerase B [EC:5.3.1.6]'},
#        {'name': 'K17195  alsE; D-allulose-6-phosphate 3-epimerase [EC:5.1.3.-]'},
#        {'name': 'K02768  fruB; fructose PTS system EIIA component [EC:2.7.1.202]'},
#        {'name': 'K02769  fruAb; fructose PTS system EIIB component [EC:2.7.1.202]'},
#        {'name': 'K02770  fruA; fructose PTS system EIIBC or EIIC component [EC:2.7.1.202]'},
#        {'name': 'K11194  levD; fructose PTS system EIIA component [EC:2.7.1.202]'},
#        {'name': 'K11195  levE; fructose PTS system EIIB component [EC:2.7.1.202]'},
#        {'name': 'K11196  levF; fructose PTS system EIIC component'},
#        {'name': 'K02771  levG; fructose PTS system EIID component'},
#        {'name': 'K02793  manXa; mannose PTS system EIIA component [EC:2.7.1.191]'},
#        {'name': 'K02794  manX; mannose PTS system EIIAB component [EC:2.7.1.191]'},
#        {'name': 'K02795  manY; mannose PTS system EIIC component'},
#        {'name': 'K02796  manZ; mannose PTS system EIID component'},
#        {'name': 'K02798  cmtB; mannitol PTS system EIIA component [EC:2.7.1.197]'},
#        {'name': 'K02800  mtlA, cmtA; mannitol PTS system EIICBA or EIICB component [EC:2.7.1.197]'},
#        {'name': 'K19270  hxpA; mannitol-1-/sugar-/sorbitol-6-phosphatase [EC:3.1.3.22 3.1.3.23 3.1.3.50]'},
#        {'name': 'K24204  hxpB; mannitol-1-/sugar-/sorbitol-6-/2-deoxyglucose-6-phosphatase [EC:3.1.3.22 3.1.3.23 3.1.3.50 3.1.3.68]'},
#        {'name': 'K02781  srlB; glucitol/sorbitol PTS system EIIA component [EC:2.7.1.198]'},
#        {'name': 'K02782  srlE; glucitol/sorbitol PTS system EIIB component [EC:2.7.1.198]'},
#        {'name': 'K02783  srlA; glucitol/sorbitol PTS system EIIC component'},
#        {'name': 'K02812  sorF, sorA; sorbose PTS system EIIA component [EC:2.7.1.206]'},
#        {'name': 'K02813  sorB; sorbose PTS system EIIB component [EC:2.7.1.206]'},
#        {'name': 'K02814  sorA, sorC; sorbose PTS system EIIC component'},
#        {'name': 'K02815  sorM, sorD; sorbose PTS system EIID component'}]},
#      {'name': '00052 Galactose metabolism [PATH:ko00052]',
#       'children': [{'name': 'K01785  galM, GALM; aldose 1-epimerase [EC:5.1.3.3]'},
#        {'name': 'K00849  galK; galactokinase [EC:2.7.1.6]'},
#        {'name': 'K00965  galT, GALT; UDPglucose--hexose-1-phosphate uridylyltransferase [EC:2.7.7.12]'},
#        {'name': 'K01784  galE, GALE; UDP-glucose 4-epimerase [EC:5.1.3.2]'},
#        {'name': 'K17716  capD; UDP-glucose 4-epimerase [EC:5.1.3.2]'},
#        {'name': 'K00963  UGP2, galU, galF; UTP--glucose-1-phosphate uridylyltransferase [EC:2.7.7.9]'},
#        {'name': 'K01835  pgm; phosphoglucomutase [EC:5.4.2.2]'},
#        {'name': 'K15778  pmm-pgm; phosphomannomutase / phosphoglucomutase [EC:5.4.2.8 5.4.2.2]'},
#        {'name': 'K15779  PGM2; phosphoglucomutase / phosphopentomutase [EC:5.4.2.2 5.4.2.7]'},
#        {'name': 'K00844  HK; hexokinase [EC:2.7.1.1]'},
#        {'name': 'K12407  GCK; glucokinase [EC:2.7.1.2]'},
#        {'name': 'K00845  glk; glucokinase [EC:2.7.1.2]'},
#        {'name': 'K01084  G6PC; glucose-6-phosphatase [EC:3.1.3.9]'},
#        {'name': 'K01190  lacZ; beta-galactosidase [EC:3.2.1.23]'},
#        {'name': 'K12111  ebgA; evolved beta-galactosidase subunit alpha [EC:3.2.1.23]'},
#        {'name': 'K12112  ebgC; evolved beta-galactosidase subunit beta'},
#        {'name': 'K12308  bgaB, lacA; beta-galactosidase [EC:3.2.1.23]'},
#        {'name': 'K12309  GLB1, ELNR1; beta-galactosidase [EC:3.2.1.23]'},
#        {'name': 'K01229  LCT; lactase-phlorizin hydrolase [EC:3.2.1.108 3.2.1.62]'},
#        {'name': 'K00704  LALBA; alpha-lactalbumin [EC:2.4.1.22]'},
#        {'name': 'K07966  B4GALT1; beta-1,4-galactosyltransferase 1 [EC:2.4.1.22 2.4.1.90 2.4.1.38 2.4.1.-]'},
#        {'name': 'K07967  B4GALT2; beta-1,4-galactosyltransferase 2 [EC:2.4.1.22 2.4.1.90 2.4.1.38 2.4.1.-]'},
#        {'name': 'K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]'},
#        {'name': 'K01854  glf; UDP-galactopyranose mutase [EC:5.4.99.9]'},
#        {'name': 'K18819  GOLS; inositol 3-alpha-galactosyltransferase [EC:2.4.1.123]'},
#        {'name': 'K06617  E2.4.1.82; raffinose synthase [EC:2.4.1.82]'},
#        {'name': 'K01189  GLA; alpha-galactosidase [EC:3.2.1.22]'},
#        {'name': 'K07406  melA; alpha-galactosidase [EC:3.2.1.22]'},
#        {'name': 'K07407  E3.2.1.22B, galA, rafA; alpha-galactosidase [EC:3.2.1.22]'},
#        {'name': 'K00011  AKR1B; aldehyde reductase [EC:1.1.1.21]'},
#        {'name': 'K02773  gatA, sgcA; galactitol PTS system EIIA component [EC:2.7.1.200]'},
#        {'name': 'K02774  gatB, sgcB; galactitol PTS system EIIB component [EC:2.7.1.200]'},
#        {'name': 'K02775  gatC, sgcC; galactitol PTS system EIIC component'},
#        {'name': 'K00094  E1.1.1.251, gatD; galactitol-1-phosphate 5-dehydrogenase [EC:1.1.1.251]'},
#        {'name': 'K21620  sorbD; galactitol 2-dehydrogenase [EC:1.1.1.16]'},
#        {'name': 'K21621  fk; tagatose kinase [EC:2.7.1.101]'},
#        {'name': 'K21622  tag6PK; D-tagatose 6-phosphate 4-epimerase [EC:5.1.3.40]'},
#        {'name': 'K00917  lacC; tagatose 6-phosphate kinase [EC:2.7.1.144]'},
#        {'name': 'K00850  pfkA, PFK; 6-phosphofructokinase 1 [EC:2.7.1.11]'},
#        {'name': 'K16370  pfkB; 6-phosphofructokinase 2 [EC:2.7.1.11]'},
#        {'name': 'K21071  pfk, pfp; ATP-dependent phosphofructokinase / diphosphate-dependent phosphofructokinase [EC:2.7.1.11 2.7.1.90]'},
#        {'name': 'K01635  lacD; tagatose 1,6-diphosphate aldolase [EC:4.1.2.40]'},
#        {'name': 'K08302  gatY-kbaY; tagatose 1,6-diphosphate aldolase GatY/KbaY [EC:4.1.2.40]'},
#        {'name': 'K16371  gatZ-kbaZ; D-tagatose-1,6-bisphosphate aldolase subunit GatZ/KbaZ'},
#        {'name': 'K00035  gal; D-galactose 1-dehydrogenase [EC:1.1.1.48]'},
#        {'name': 'K22215  galD; galactose dehydrogenase [EC:1.1.1.48 1.1.1.120]'},
#        {'name': 'K18124  gdh2, gdhA; glucose/galactose 1-dehydrogenase (NADP+) [EC:1.1.1.360]'},
#        {'name': 'K18125  ssgdh; aldose 1-dehydrogenase [NAD(P)+] [EC:1.1.1.359]'},
#        {'name': 'K04618  GAOA; galactose oxidase [EC:1.1.3.9]'},
#        {'name': 'K01684  dgoD; galactonate dehydratase [EC:4.2.1.6]'},
#        {'name': 'K05308  gnaD; gluconate/galactonate dehydratase [EC:4.2.1.140]'},
#        {'name': 'K11395  kdpgA; 2-dehydro-3-deoxy-phosphogluconate/2-dehydro-3-deoxy-6-phosphogalactonate aldolase [EC:4.1.2.55]'},
#        {'name': 'K18127  kdgA; 2-dehydro-3-deoxy-D-gluconate aldolase [EC:4.1.2.51]'},
#        {'name': 'K00883  dgoK; 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.58]'},
#        {'name': 'K18126  sskdgK; 2-dehydro-3-deoxygluconokinase / 2-dehydro-3-deoxygalactonokinase [EC:2.7.1.178]'},
#        {'name': 'K01631  dgoA; 2-dehydro-3-deoxyphosphogalactonate aldolase [EC:4.1.2.21]'},
#        {'name': 'K01819  E5.3.1.26, lacA, lacB; galactose-6-phosphate isomerase [EC:5.3.1.26]'},
#        {'name': 'K01220  E3.2.1.85, lacG; 6-phospho-beta-galactosidase [EC:3.2.1.85]'},
#        {'name': 'K02786  lacF; lactose PTS system EIIA component [EC:2.7.1.207]'},
#        {'name': 'K02788  lacE; lactose PTS system EIICB component [EC:2.7.1.207]'},
#        {'name': 'K01193  INV, sacA; beta-fructofuranosidase [EC:3.2.1.26]'},
#        {'name': 'K06611  E2.4.1.67; stachyose synthetase [EC:2.4.1.67]'},
#        {'name': 'K12047  MGAM; maltase-glucoamylase [EC:3.2.1.20 3.2.1.3]'},
#        {'name': 'K01187  malZ; alpha-glucosidase [EC:3.2.1.20]'},
#        {'name': 'K12316  GAA; lysosomal alpha-glucosidase [EC:3.2.1.20]'},
#        {'name': 'K12317  GANC; neutral alpha-glucosidase C [EC:3.2.1.20]'},
#        {'name': 'K01182  IMA, malL; oligo-1,6-glucosidase [EC:3.2.1.10]'},
#        {'name': 'K01203  SI; sucrase-isomaltase [EC:3.2.1.48 3.2.1.10]'},
#        {'name': 'K02744  agaF; N-acetylgalactosamine PTS system EIIA component [EC:2.7.1.-]'},
#        {'name': 'K02745  agaV; N-acetylgalactosamine PTS system EIIB component [EC:2.7.1.-]'},
#        {'name': 'K02746  agaW; N-acetylgalactosamine PTS system EIIC component'},
#        {'name': 'K02747  agaE; N-acetylgalactosamine PTS system EIID component'},
#        {'name': 'K02079  agaA; N-acetylgalactosamine-6-phosphate deacetylase [EC:3.5.1.25]'},
#        {'name': 'K02080  agaI; galactosamine-6-phosphate isomerase [EC:5.3.1.-]'},
#        {'name': 'K10984  agaB; galactosamine PTS system EIIB component [EC:2.7.1.-]'},
#        {'name': 'K10985  agaC; galactosamine PTS system EIIC component'},
#        {'name': 'K10986  agaD; galactosamine PTS system EIID component'}]},
#      {'name': '00053 Ascorbate and aldarate metabolism [PATH:ko00053]',
#       'children': [{'name': 'K00012  UGDH, ugd; UDPglucose 6-dehydrogenase [EC:1.1.1.22]'},
#        {'name': 'K12447  USP; UDP-sugar pyrophosphorylase [EC:2.7.7.64]'},
#        {'name': 'K16190  GLCAK; glucuronokinase [EC:2.7.1.43]'},
#        {'name': 'K00699  UGT; glucuronosyltransferase [EC:2.4.1.17]'},
#        {'name': 'K01195  uidA, GUSB; beta-glucuronidase [EC:3.2.1.31]'},
#        {'name': 'K14756  KL; klotho [EC:3.2.1.31]'},
#        {'name': 'K00469  MIOX; inositol oxygenase [EC:1.13.99.1]'},
#        {'name': 'K00002  AKR1A1, adh; alcohol dehydrogenase (NADP+) [EC:1.1.1.2]'},
#        {'name': 'K01053  gnl, RGN; gluconolactonase [EC:3.1.1.17]'},
#        {'name': 'K00103  GULO; L-gulonolactone oxidase [EC:1.1.3.8]'},
#        {'name': "K10046  GME; GDP-D-mannose 3', 5'-epimerase [EC:5.1.3.18 5.1.3.-]"},
#        {'name': 'K14190  VTC2_5; GDP-L-galactose phosphorylase [EC:2.7.7.69]'},
#        {'name': 'K10047  VTC4; inositol-phosphate phosphatase / L-galactose 1-phosphate phosphatase [EC:3.1.3.25 3.1.3.93]'},
#        {'name': 'K18649  IMPL2; inositol-phosphate phosphatase / L-galactose 1-phosphate phosphatase / histidinol-phosphatase [EC:3.1.3.25 3.1.3.93 3.1.3.15]'},
#        {'name': 'K00064  E1.1.1.122; D-threo-aldose 1-dehydrogenase [EC:1.1.1.122]'},
#        {'name': 'K17744  GalDH; L-galactose dehydrogenase [EC:1.1.1.316]'},
#        {'name': 'K00225  GLDH; L-galactono-1,4-lactone dehydrogenase [EC:1.3.2.3]'},
# ...
#        {'name': 'K11039  hld; delta-hemolysin'},
#        {'name': 'K20335  psmA1_2; phenol-soluble modulin alpha 1/2'},
#        {'name': 'K20336  psmA3; phenol-soluble modulin alpha 3'},
#        {'name': 'K20337  psmB; phenol-soluble modulin beta'},
#        {'name': 'K20554  rnaIII; small regulatory RNA RNAIII'},
#        {'name': 'K20338  rot; MarR family transcriptional regulator, global regulator for virulence'},
#        {'name': 'K20339  agrC2; two-component system, LytTR family, sensor histidine kinase AgrC2 [EC:2.7.13.3]'},
#        {'name': 'K20340  agrA2; two-component system, LytTR family, response regulator AgrA2'},
#        {'name': 'K11063  tcdAB; toxin A/B'},
#        {'name': 'K16619  plc, cpa; phospholipase C / alpha-toxin [EC:3.1.4.3]'},
#        {'name': 'K11031  slo; thiol-activated cytolysin'},
#        {'name': 'K12415  comC; competence-stimulating peptide'},
#        {'name': 'K23133  comC; competence-stimulating peptide'},
#        {'name': 'K12292  comA; ATP-binding cassette, subfamily C, bacterial, competence factor transporting protein [EC:3.4.22.-]'},
#        {'name': 'K12293  comB; competence factor transport accessory protein ComB'},
#        {'name': 'K12294  comD; two-component system, LytTR family, sensor histidine kinase ComD [EC:2.7.13.3]'},
#        {'name': 'K12295  comE; two-component system, LytTR family, response regulator ComE'},
#        {'name': 'K20321  nlmA; mutacin IV'},
#        {'name': 'K20322  nlmB; mutacin IV'},
#        {'name': 'K20323  nlmC, cipB; mutacin V'},
#        {'name': 'K20324  nlmD; mutacin VI'},
#        {'name': 'K20341  blpL, cipI; immunity protein'},
#        {'name': 'K14982  ciaH; two-component system, OmpR family, sensor histidine kinase CiaH [EC:2.7.13.3]'},
#        {'name': 'K14983  ciaR; two-component system, OmpR family, response regulator CiaR'},
#        {'name': 'K15580  oppA, mppA; oligopeptide transport system substrate-binding protein'},
#        {'name': 'K15581  oppB; oligopeptide transport system permease protein'},
#        {'name': 'K15582  oppC; oligopeptide transport system permease protein'},
#        {'name': 'K15583  oppD; oligopeptide transport system ATP-binding protein'},
#        {'name': 'K10823  oppF; oligopeptide transport system ATP-binding protein'},
#        {'name': 'K20342  comR; HTH-type transcriptional regulator, regulator for ComX'},
#        {'name': 'K12296  comX1_2; competence protein ComX'},
#        {'name': 'K20343  blpC; peptide pheromone BlpC'},
#        {'name': 'K20344  blpA, lagD; ATP-binding cassette, subfamily C, bacteriocin exporter'},
#        {'name': 'K20345  blpB; membrane fusion protein, peptide pheromone/bacteriocin exporter'},
#        {'name': 'K20373  rgg2; HTH-type transcriptional regulator, SHP2-responsive activator'},
#        {'name': 'K20374  rgg3; HTH-type transcriptional regulator, SHP3-responsive repressor'},
#        {'name': 'K02035  ABC.PE.S; peptide/nickel transport system substrate-binding protein'},
#        {'name': 'K02033  ABC.PE.P; peptide/nickel transport system permease protein'},
#        {'name': 'K02034  ABC.PE.P1; peptide/nickel transport system permease protein'},
#        {'name': 'K02031  ddpD; peptide/nickel transport system ATP-binding protein'},
#        {'name': 'K02032  ddpF; peptide/nickel transport system ATP-binding protein'},
#        {'name': 'K20375  ropB, rgg1; HTH-type transcriptional regulator, pheromone-responsive regulator'},
#        {'name': 'K01364  speB; streptopain [EC:3.4.22.10]'},
#        {'name': 'K01635  lacD; tagatose 1,6-diphosphate aldolase [EC:4.1.2.40]'},
#        {'name': 'K20376  prgQ; peptide inhibitor iCF10'},
#        {'name': 'K03217  yidC, spoIIIJ, OXA1, ccfA; YidC/Oxa1 family membrane protein insertase'},
#        {'name': 'K20377  prgX; HTH-type transcriptional regulator, major conjugation operon repressor'},
#        {'name': 'K20378  iad1; sex pheromone inhibitor iAD1'},
#        {'name': 'K20379  cad; sex pheromone cAD1'},
#        {'name': 'K20380  traA; HTH-type transcriptional regulator, pheromone-responsive repressor'},
#        {'name': 'K20381  traE1; regulatory protein'},
#        {'name': 'K20382  asa1; aggregation substance'},
#        {'name': 'K08605  gelE; coccolysin [EC:3.4.24.30]'},
#        {'name': 'K01318  sspA; glutamyl endopeptidase [EC:3.4.21.19]'},
#        {'name': 'K20383  cylLL; CylL-L protein'},
#        {'name': 'K20384  cylLS; CylL-S protein'},
#        {'name': 'K20385  cylM; CylM protein'},
#        {'name': 'K20386  cylB; ATP-binding cassette, subfamily B, bacterial CylB'},
#        {'name': 'K14645  K14645; serine protease [EC:3.4.21.-]'},
#        {'name': 'K20387  cylR1; regulatory protein CylR1'},
#        {'name': 'K20388  cylR2; HTH-type transcriptional regulator, cytolysin regulator'},
#        {'name': 'K02253  comX; competence protein ComX'},
#        {'name': 'K02251  comQ; competence protein ComQ'},
#        {'name': 'K07680  comP; two-component system, NarL family, sensor histidine kinase ComP [EC:2.7.13.3]'},
#        {'name': 'K07691  comA; two-component system, NarL family, competent response regulator ComA'},
#        {'name': 'K02252  comS; competence protein ComS'},
#        {'name': 'K02250  comK; competence protein ComK'},
#        {'name': 'K15654  srfAA, lchAA; surfactin family lipopeptide synthetase A'},
#        {'name': 'K15655  srfAB, lchAB; surfactin family lipopeptide synthetase B'},
#        {'name': 'K15656  srfAC, lchAC; surfactin family lipopeptide synthetase C'},
#        {'name': 'K15657  srfATE, srfAD, lchAD; external thioesterase TEII'},
#        {'name': 'K06353  phrC; phosphatase RapC regulator'},
#        {'name': 'K06355  phrF; phosphatase RapF regulator'},
#        {'name': 'K06358  phrK; phosphatase RapK regulator'},
#        {'name': 'K06356  phrG; phosphatase RapG regulator'},
#        {'name': 'K20389  phrH; phosphatase RapH regulator'},
#        {'name': 'K06352  phrA; phosphatase RapA inhibitor'},
#        {'name': 'K06354  phrE; phosphatase RapE regulator'},
#        {'name': 'K12257  secDF; SecD/SecF fusion protein'},
#        {'name': 'K03073  secE; preprotein translocase subunit SecE'},
#        {'name': 'K03075  secG; preprotein translocase subunit SecG'},
#        {'name': 'K03076  secY; preprotein translocase subunit SecY'},
#        {'name': 'K03210  yajC; preprotein translocase subunit YajC'},
#        {'name': 'K03070  secA; preprotein translocase subunit SecA [EC:7.4.2.8]'},
#        {'name': 'K03110  ftsY; fused signal recognition particle receptor'},
#        {'name': 'K03071  secB; preprotein translocase subunit SecB'},
#        {'name': 'K03106  SRP54, ffh; signal recognition particle subunit SRP54 [EC:3.6.5.4]'},
#        {'name': 'K06361  rapC; response regulator aspartate phosphatase C [EC:3.1.-.-]'},
#        {'name': 'K06364  rapF; response regulator aspartate phosphatase F [EC:3.1.-.-]'},
#        {'name': 'K06369  rapK; response regulator aspartate phosphatase K [EC:3.1.-.-]'},
#        {'name': 'K06365  rapG; response regulator aspartate phosphatase G [EC:3.1.-.-]'},
#        {'name': 'K06366  rapH; response regulator aspartate phosphatase H [EC:3.1.-.-]'},
#        {'name': 'K06359  rapA, spo0L; response regulator aspartate phosphatase A (stage 0 sporulation protein L) [EC:3.1.-.-]'},
#        {'name': 'K06363  rapE; response regulator aspartate phosphatase E [EC:3.1.-.-]'},
#        {'name': 'K06360  rapB; response regulator aspartate phosphatase B [EC:3.1.-.-]'},
#        {'name': 'K07692  degU; two-component system, NarL family, response regulator DegU'},
#        {'name': 'K02490  spo0F; two-component system, response regulator, stage 0 sporulation protein F'},
#        {'name': 'K06375  spo0B; stage 0 sporulation protein B (sporulation initiation phosphotransferase) [EC:2.7.-.-]'},
#        {'name': 'K07699  spo0A; two-component system, response regulator, stage 0 sporulation protein A'},
#        {'name': 'K20390  papR; regulatory peptide PapR'},
#        {'name': 'K08777  nprB; neutral peptidase B [EC:3.4.24.-]'},
#        {'name': 'K20391  plcR; HTH-type transcriptional regulator, pleiotropic regulator of extracellular virulence genes'},
#        {'name': 'K01114  plc; phospholipase C [EC:3.1.4.3]'},
#        {'name': 'K11035  hblAB; hemolysin BL binding component'},
#        {'name': 'K11036  hblC; hemolysin BL lytic component L2'},
#        {'name': 'K11037  hblD; hemolysin BL lytic component L1'},
#        {'name': 'K11033  nheA; non-hemolytic enterotoxin A'},
#        {'name': 'K11034  nheBC; non-hemolytic enterotoxin B/C'},
#        {'name': 'K20480  nprR, nprA; HTH-type transcriptional regulator, quorum sensing regulator NprR'},
#        {'name': 'K20481  nprX, nprRB; regulatory peptide NprX'},
#        {'name': 'K20482  nisA, spaS, epiA; lantibiotic bacteriocin'},
#        {'name': 'K20483  nisB, spaB, epiB; lantibiotic biosynthesis protein'},
#        {'name': 'K20484  nisC, spaC, epiC; lantibiotic biosynthesis protein'},
#        {'name': 'K20485  nisT, spaT; ATP-binding cassette, subfamily B, bacterial NisT/SpaT'},
#        {'name': 'K20486  nisP, epiP; lantibiotic leader peptide-processing serine protease [EC:3.4.21.-]'},
#        {'name': 'K20487  nisK, spaK; two-component system, OmpR family, lantibiotic biosynthesis sensor histidine kinase NisK/SpaK [EC:2.7.13.3]'},
#        {'name': 'K20488  nisR, spaR; two-component system, OmpR family, lantibiotic biosynthesis response regulator NisR/SpaR'},
#        {'name': 'K20489  nisI; lantibiotic immunity protein'},
#        {'name': 'K20490  nisF, spaF, cprA, epiF; lantibiotic transport system ATP-binding protein'},
#        {'name': 'K20491  nisE, spaE, cprB, epiE; lantibiotic transport system permease protein'},
#        {'name': 'K20492  nisG, spaG, cprC; lantibiotic transport system permease protein'},
#        {'name': 'K20494  epiG; lantibiotic transport system permease protein'}]}]},
#    {'name': '09142 Cell motility',
#     'children': [{'name': '02030 Bacterial chemotaxis [PATH:ko02030]',
#       'children': [{'name': 'K03406  mcp; methyl-accepting chemotaxis protein'},
#        {'name': 'K05874  tsr; methyl-accepting chemotaxis protein I, serine sensor receptor'},
#        {'name': 'K05875  tar; methyl-accepting chemotaxis protein II, aspartate sensor receptor'},
#        {'name': 'K05876  trg; methyl-accepting chemotaxis protein III, ribose and galactose sensor receptor'},
#        {'name': 'K05877  tap; methyl-accepting chemotaxis protein IV, peptide sensor receptor'},
#        {'name': 'K03776  aer; aerotaxis receptor'},
#        {'name': 'K10108  malE; maltose/maltodextrin transport system substrate-binding protein'},
#        {'name': 'K10439  rbsB; ribose transport system substrate-binding protein'},
#        {'name': 'K10540  mglB; methyl-galactoside transport system substrate-binding protein'},
#        {'name': 'K12368  dppA; dipeptide transport system substrate-binding protein'},
#        {'name': 'K03407  cheA; two-component system, chemotaxis family, sensor kinase CheA [EC:2.7.13.3]'},
#        {'name': 'K03408  cheW; purine-binding chemotaxis protein CheW'},
#        {'name': 'K03413  cheY; two-component system, chemotaxis family, chemotaxis protein CheY'},
#        {'name': 'K03410  cheC; chemotaxis protein CheC'},
#        {'name': 'K03414  cheZ; chemotaxis protein CheZ'},
#        {'name': 'K03409  cheX; chemotaxis protein CheX'},
#        {'name': 'K03412  cheB; two-component system, chemotaxis family, protein-glutamate methylesterase/glutaminase [EC:3.1.1.61 3.5.1.44]'},
#        {'name': 'K13924  cheBR; two-component system, chemotaxis family, CheB/CheR fusion protein [EC:2.1.1.80 3.1.1.61]'},
#        {'name': 'K03415  cheV; two-component system, chemotaxis family, chemotaxis protein CheV'},
#        {'name': 'K03411  cheD; chemotaxis protein CheD [EC:3.5.1.44]'},
#        {'name': 'K00575  cheR; chemotaxis protein methyltransferase CheR [EC:2.1.1.80]'},
#        {'name': 'K02410  fliG; flagellar motor switch protein FliG'},
#        {'name': 'K02416  fliM; flagellar motor switch protein FliM'},
#        {'name': 'K02417  fliN; flagellar motor switch protein FliN'},
#        {'name': 'K02556  motA; chemotaxis protein MotA'},
#        {'name': 'K02557  motB; chemotaxis protein MotB'}]},
#      {'name': '02040 Flagellar assembly [PATH:ko02040]',
#       'children': [{'name': 'K02408  fliE; flagellar hook-basal body complex protein FliE'},
#        {'name': 'K02409  fliF; flagellar M-ring protein FliF'},
#        {'name': 'K02410  fliG; flagellar motor switch protein FliG'},
#        {'name': 'K02411  fliH; flagellar assembly protein FliH'},
#        {'name': 'K02412  fliI; flagellum-specific ATP synthase [EC:7.4.2.8]'},
#        {'name': 'K02413  fliJ; flagellar protein FliJ'},
#        {'name': 'K02414  fliK; flagellar hook-length control protein FliK'},
#        {'name': 'K02415  fliL; flagellar protein FliL'},
#        {'name': 'K02416  fliM; flagellar motor switch protein FliM'},
#        {'name': 'K02417  fliN; flagellar motor switch protein FliN'},
#        {'name': 'K02418  fliO, fliZ; flagellar protein FliO/FliZ'},
#        {'name': 'K02419  fliP; flagellar biosynthesis protein FliP'},
#        {'name': 'K02420  fliQ; flagellar biosynthesis protein FliQ'},
#        {'name': 'K02421  fliR; flagellar biosynthesis protein FliR'},
#        {'name': 'K03516  flhE; flagellar protein FlhE'},
#        {'name': 'K02400  flhA; flagellar biosynthesis protein FlhA'},
#        {'name': 'K02401  flhB; flagellar biosynthesis protein FlhB'},
#        {'name': 'K13820  fliR-flhB; flagellar biosynthesis protein FliR/FlhB'},
#        {'name': 'K02386  flgA; flagellar basal body P-ring formation protein FlgA'},
#        {'name': 'K02387  flgB; flagellar basal-body rod protein FlgB'},
#        {'name': 'K02388  flgC; flagellar basal-body rod protein FlgC'},
#        {'name': 'K02389  flgD; flagellar basal-body rod modification protein FlgD'},
#        {'name': 'K02390  flgE; flagellar hook protein FlgE'},
#        {'name': 'K02391  flgF; flagellar basal-body rod protein FlgF'},
#        {'name': 'K02392  flgG; flagellar basal-body rod protein FlgG'},
#        {'name': 'K02393  flgH; flagellar L-ring protein FlgH'},
#        {'name': 'K02394  flgI; flagellar P-ring protein FlgI'},
#        {'name': 'K02395  flgJ; peptidoglycan hydrolase FlgJ'},
#        {'name': 'K02396  flgK; flagellar hook-associated protein 1'},
#        {'name': 'K02397  flgL; flagellar hook-associated protein 3 FlgL'},
#        {'name': 'K24344  flgO; flagellar H-ring protein FlgO'},
#        {'name': 'K09860  flgP; outer membrane protein FlgP'},
#        {'name': 'K24346  flgQ; flagellar motility protein FlgQ'},
#        {'name': 'K24343  flgT; flagellar H-ring protein FlgT'},
#        {'name': 'K21217  motX; sodium-type polar flagellar protein MotX'},
#        {'name': 'K21218  motY; sodium-type flagellar protein MotY'},
#        {'name': 'K02406  fliC, hag; flagellin'},
#        {'name': 'K02407  fliD; flagellar hook-associated protein 2'},
#        {'name': 'K02422  fliS; flagellar secretion chaperone FliS'},
#        {'name': 'K02423  fliT; flagellar protein FliT'},
#        {'name': 'K02556  motA; chemotaxis protein MotA'},
#        {'name': 'K02557  motB; chemotaxis protein MotB'},
#        {'name': 'K10564  motC; chemotaxis protein MotC'},
#        {'name': 'K10565  motD; chemotaxis protein MotD'},
#        {'name': 'K02398  flgM; negative regulator of flagellin synthesis FlgM'},
#        {'name': 'K02399  flgN; flagellar biosynthesis protein FlgN'},
#        {'name': 'K02424  fliY, tcyA; L-cystine transport system substrate-binding protein'},
#        {'name': 'K02425  fliZ; regulator of sigma S factor FliZ'},
#        {'name': 'K03086  rpoD; RNA polymerase primary sigma factor'},
#        {'name': 'K10941  flrA, fleQ, flaK; sigma-54 dependent transcriptional regulator, flagellar regulatory protein'},
#        {'name': 'K02403  flhD; flagellar transcriptional activator FlhD'},
#        {'name': 'K02402  flhC; flagellar transcriptional activator FlhC'},
#        {'name': 'K03092  rpoN; RNA polymerase sigma-54 factor'},
#        {'name': 'K10943  flrC, fleR, flaM; two-component system, response regulator FlrC'},
#        {'name': 'K02405  fliA, whiG; RNA polymerase sigma factor FliA'}]}]}]}]

# %%
with open('Data/Function_Annotations/KEGG/Dokdonia_KEGG_pathways.json', 'w') as outfile:
        json.dump(strain_kegg_pathways, outfile)

# %%
# Write Excel with cluster results

with open('Data/Function_Annotations/KEGG/kegg_pathways.json') as json_file:
    kegg_pathways = json.load(json_file)['children']
    
gbk = Dc.GenomeGBK('Data/DokdoniaMED134.gbk')
    
eggNOG = pd.read_excel('Data/Function_Annotations/KEGG/result_eggNOGMapper.xlsx', header=2)
ko_pathway_dict = Dc.getKEGGPathwayDict(kegg_pathways)
gene_ko_dict= Dc.getGeneKOs(eggNOG)

patric_features = pd.read_csv('Data/Function_Annotations/PATRIC/Dokdonia_MED134_Craig_PATRIC_genome_feature.csv')
patric_pathways = pd.read_csv('Data/Function_Annotations/PATRIC/Dokdonia_MED134_PATRIC_pathways.csv')
patric_pathways_genes = pd.read_csv('Data/Function_Annotations/PATRIC/Dokdonia_MED134_Craig_PATRIC_pathways_genes.csv')

Dc.writeExcelOfClusterGenes(ranked_clusters['TPM'], 'Results/TPM_clusters_genes_pathways.xlsx',
                        gbk, patric_features, patric_pathways_genes, patric_pathways,
                        gene_ko_dict, ko_pathway_dict)

Dc.writeExcelOfClusterGenes(ranked_clusters['TC'], 'Results/TC_clusters_genes_pathways.xlsx',
                        gbk, patric_features, patric_pathways_genes, patric_pathways,
                        gene_ko_dict, ko_pathway_dict)

# %% [markdown]
# ## Analyzing which genes are across-temperature, DE (LTR test) within clusters

# %%
cluster_stats = {}
for data_type in data_types:
    total_genes_in_clusters = [g for cluster in clusters[data_type].values() for g in cluster]
    DE_genes_in_clusters = np.intersect1d(DE_results['all'].index, total_genes_in_clusters)
    cluster_stats[data_type] = {'total genes': len(total_genes_in_clusters),
                               'DE fraction': len(DE_genes_in_clusters)/len(total_genes_in_clusters)}
    
pd.DataFrame(cluster_stats)
# Out:
#                       TC         TPM
# total genes  1052.000000  948.000000
# DE fraction     0.908745    0.931435

# %%
cluster_stats = {}
for data_type in data_types:
    cluster_stats[data_type] = {}
    for cluster_id, cluster in clusters[data_type].items():
        cluster_stats[data_type][cluster_id] = {
            'total genes': len(cluster),
            'DE fraction': len(np.intersect1d(DE_results['all'].index,cluster))/len(cluster)
        }

# %%
Dc.getMetaMatrix(counts_T)
# Out:
#         lighting  temperature replicate
# D_10_R1        D           10        R1
# D_10_R2        D           10        R2
# D_10_R3        D           10        R3
# D_34_R1        D           34        R1
# D_34_R2        D           34        R2
# D_34_R3        D           34        R3
# D_34_R4        D           34        R4

# %%
cluster_stats['TC']['C6']
# Out:
# {'total genes': 75, 'DE fraction': 0.7733333333333333}

# %% [markdown]
# ## Evaluating fold change in clusters Clusters $C_1$, $C_3$ and $C_2$, $C_5$.
#
# Basically, I get that these genes are not DE according to  the Wald test in DeSeq2. However, data clearly shows a patter... DeSeq2 being very conservative?

# %%
p_value_cutoff = 0.05
fold_cutoff = k = 0.1

T1, T2 = 34, 25
counts_T = counts[counts.filter(regex=f'{T1}|{T2}|index').columns]
counts_T_C3 = counts_T[counts_T['index'].isin(clusters['TC']['C3'])]

T_res, T_stats = Dc.runDEtest(counts_T_C3, test='Wald', alpha=p_value_cutoff,
                                  formula='~ temperature', log2fold_cutoff=k)

# %%
T_res
# Out:
#                  baseMean  log2FoldChange     lfcSE       stat        pvalue  \
# MED134_04624  1239.139427        0.197042  0.015828   6.131097  8.727541e-10
# MED134_03499  2219.167085        0.185841  0.013400   6.406053  1.493354e-10
# MED134_07626   853.915948        0.418700  0.026521  12.017057  2.890864e-33
# MED134_10595   689.031967        0.206668  0.014264   7.478255  7.531590e-14
# MED134_11826   704.764486        0.132876  0.010406   3.159426  1.580803e-03
# MED134_11831  1004.845845        0.192995  0.013938   6.672189  2.520156e-11
#
#                       padj         index
# MED134_04624  1.274221e-08  MED134_04624
# MED134_03499  2.725371e-09  MED134_03499
# MED134_07626  2.110330e-31  MED134_07626
# MED134_10595  2.749030e-12  MED134_10595
# MED134_11826  1.923310e-02  MED134_11826
# MED134_11831  6.132379e-10  MED134_11831

# %%
# Plotting both databases at the same time
Dc.plotSystemsAndSubsystemsWebPage(clusters, cluster_data, p_Data_paths,
                                   plot_first_N=10, color='#dd912d',
                                   img_folder_name='iplots_imgs')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#     <div id="static-widget-iplots_imgs">
#       <b>Cluster ID</b>: <select name="cluster_id" onchange="interactUpdate(this);"> <option value="C0"  selected >C0</option>      <option value="C1" >C1</option>      <option value="C2" >C2</option>      <option value="C3" >C3</option>      <option value="C4" >C4</option>      <option value="C5" >C5</option>      <option value="C6" >C6</option></select>
# <br>
# <b>Normalization</b>: <select name="data_normalization" onchange="interactUpdate(this);"> <option value="TPM"  selected >TPM</option>      <option value="TC" >TC</option></select>
# <br>
# <b>Database</b>: <select name="database" onchange="interactUpdate(this);"> <option value="KEGG"  selected >KEGG</option>      <option value="PATRIC" >PATRIC</option></select>
# <br>
# <b>Level</b>: <select name="system_type" onchange="interactUpdate(this);"> <option value="system"  selected >system</option>      <option value="subsystem" >subsystem</option></select> <!--Same order as ipywidgets, also defined before script-->
#
#     <div name="cluster_idC0data_normalizationTPMdatabaseKEGGsystem_typesystem" style="display:block">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTPMdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTPMdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTPMdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTPMdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTPMdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTPMdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTPMdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTCdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTCdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTCdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTCdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTCdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTCdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC0data_normalizationTCdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC0data_normalizationTCdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTPMdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTPMdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTPMdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTPMdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTPMdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTPMdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTPMdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTPMdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTCdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTCdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTCdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTCdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTCdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTCdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC1data_normalizationTCdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC1data_normalizationTCdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTPMdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTPMdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTPMdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTPMdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTPMdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTPMdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTPMdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTPMdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTCdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTCdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTCdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTCdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTCdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTCdatabasePATRICsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC2data_normalizationTCdatabasePATRICsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC2data_normalizationTCdatabasePATRICsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC3data_normalizationTPMdatabaseKEGGsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC3data_normalizationTPMdatabaseKEGGsystem_typesystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC3data_normalizationTPMdatabaseKEGGsystem_typesubsystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC3data_normalizationTPMdatabaseKEGGsystem_typesubsystem.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="cluster_idC3data_normalizationTPMdatabasePATRICsystem_typesystem" style="display:none">
#       <img src="iplots_imgs_imgs/cluster_idC3data_normalizationTPMdatabasePATRICsystem_typesystem.png" style="max-wi

# %% [markdown]
# # Analyzing genes in pathways
#
# What you have to do is to remove KEGG pathways that don't make sense in a prokaryote... most genes have redundant pathways assigned. So, remove Peroxisome, and perhaps other ones, like some signaling pathways.

# %%
gene_list = clusters['TC']['C3']


for gene_id in gene_list:
    g_info = gbk.getGeneInfo(gene_id)
    if 'note' in g_info.keys():
        if 'heat shock' in g_info['note'][0].lower():
            print(gene_id)

# %%
with open('Data/Function_Annotations/KEGG/kegg_pathways.json') as json_file:
    kegg_pathways = json.load(json_file)['children']
gbk = Dc.GenomeGBK('Data/DokdoniaMED134.gbk')

kegg_dict = Dc.assignSystemsToEnzymes(kegg_pathways)
eggNOG = pd.read_excel('Data/Function_Annotations/KEGG/result_eggNOGMapper.xlsx', header=2)
ko_pathway_dict = Dc.getKEGGPathwayDict(kegg_pathways)
gene_ko_dict= Dc.getGeneKOs(eggNOG)

# %% [markdown]
# The KEGG pathway Peroxisome doesn't make much sense in Dokdonia. Let's look at the genes that form this pathway

# %%
peroxigenes = Dc.getGenesInKEGGsystem(ko_pathway_dict, gene_ko_dict,
                                      'Peroxisome', system_type='subsystem')

[(gene_id, gbk.getGeneInfo(gene_id)['product'][0]) for gene_id in peroxigenes]
# Out:
# [('MED134_06289', 'hydroxymethylglutaryl-CoA lyase'),
#  ('MED134_05414', 'long-chain-fatty-acid-CoA ligase'),
#  ('MED134_04964', 'superoxide dismutase [Cu-Zn]'),
#  ('MED134_01785', 'aminotransferase class-V'),
#  ('MED134_09101', 'superoxide dismutase'),
#  ('MED134_10845', 'mevalonate kinase'),
#  ('MED134_14141', 'isocitrate dehydrogenase')]

# %%
subsystem_name = 'Peroxisome'
subsystem_genes = Dc.getGenesInKEGGsystem(ko_pathway_dict, gene_ko_dict,
                                          subsystem_name, system_type='subsystem')

total_genes = [(gene_id, gbk.getGeneInfo(gene_id)['product'][0]) 
               for gene_id in subsystem_genes]
genes_in_cluster = [(gene_id, gbk.getGeneInfo(gene_id)['product'][0]) 
                    for gene_id in subsystem_genes if gene_id in clusters['TC']['C0']]

print(total_genes)
print(genes_in_cluster)
# Out:
# [('MED134_06289', 'hydroxymethylglutaryl-CoA lyase'), ('MED134_05414', 'long-chain-fatty-acid-CoA ligase'), ('MED134_04964', 'superoxide dismutase [Cu-Zn]'), ('MED134_01785', 'aminotransferase class-V'), ('MED134_09101', 'superoxide dismutase'), ('MED134_10845', 'mevalonate kinase'), ('MED134_14141', 'isocitrate dehydrogenase')]
# []

# %%
cluster_match_TPM_TC = [
    ('C0', 'C4'), ('C1', 'C5'), 
    ('C2', 'C6'), ('C3', 'C1'),
    ('C4', 'C0'), ('C5', 'C2')
]

TC_cluster_colors =     {
        'C0': '#3d03fc', 'C1': '#036bfc', 'C2': '#03adfc',
        'C3': '#fc4e03', 'C4': '#fc0303', 'C5': '#fc7703', 
        'C6': '#03fc7b', 'No cluster': 'white'
    }

cluster_colors = {
    'TC': TC_cluster_colors,
    'TPM':
    {
        'C0': TC_cluster_colors['C4'], 'C1': TC_cluster_colors['C5'],
        'C2': TC_cluster_colors['C6'], 'C3': TC_cluster_colors['C1'],
        'C4': TC_cluster_colors['C0'], 'C5': TC_cluster_colors['C2'],
        'No cluster': 'white'
    }
}
    
Dc.plotSystemsAndSubsystemsStacked(p_Data_paths, cluster_colors, 'iplots_Stacked')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
#     <div id="static-widget-iplots_Stacked">
#       <b>Normalization</b>: <select name="data_normalization" onchange="interactUpdate(this);"> <option value="TPM"  selected >TPM</option>      <option value="TC" >TC</option></select>
# <br>
# <b>Database</b>: <select name="database" onchange="interactUpdate(this);"> <option value="KEGG"  selected >KEGG</option>      <option value="PATRIC" >PATRIC</option></select>
# <br>
# <b>Level</b>: <select name="system_type" onchange="interactUpdate(this);"> <option value="system"  selected >system</option>      <option value="subsystem" >subsystem</option></select>
# <br>
# <b>p-value cutoff</b> = <label id="tpvalue_cutoff_label" for="tpvalue_cutoff">0.1</label><input type="range" id="tpvalue_cutoff" name="tpvalue_cutoff" min="0.05" max="1" step="0.05" value="0.1" style="width:350px" oninput="interactUpdate(this);" onchange="interactUpdate(this);"> <!--Same order as ipywidgets, also defined before script-->
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.05" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.05.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.1" style="display:block">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.1.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.15000000000000002" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.15000000000000002.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.2" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.2.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.25" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.25.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.3" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.3.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.35000000000000003" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.35000000000000003.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.4" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.4.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.45" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.45.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.5" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.5.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.55" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.55.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.6000000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.6000000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.6500000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.6500000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.7000000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.7000000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.7500000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.7500000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.8" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.8.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.8500000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.8500000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.9000000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.9000000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.9500000000000001" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff0.9500000000000001.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff1" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesystemtpvalue_cutoff1.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.05" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.05.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.1" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.1.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.15000000000000002" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.15000000000000002.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.2" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.2.png" style="max-width:100%; height:auto"/>
#     </div>
#
#     <div name="data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.25" style="display:none">
#       <img src="iplots_Stacked_imgs/data_normalizationTPMdatabaseKEGGsystem_typesubsystemtpvalue_cutoff0.25.png" style="max-width:100%; height:a
